# %%
import pandas as pd

# %%
articulos = pd.read_csv("df_articulos_lt.csv")
kits = pd.read_excel("kits.xlsx")
ventas = pd.read_csv("ventas.csv")

# %%
articulos
# Out:
#              articulo  LT_meses
# 0             00046br       4.0
# 1             00051br       4.0
# 2              00259n       4.0
# 3            00328731       4.0
# 4             00359br       4.0
# ...               ...       ...
# 6673   zyb-0807r/489a       4.0
# 6674    zyb-1214l/243       4.0
# 6675    zyb-1216l/198       4.0
# 6676    zyb-1315r/130       4.0
# 6677  zyb-2024l/535-3       4.0
#
# [6678 rows x 2 columns]

# %%
ventas
# Out:
#        cia       fecha  codigo                              razon_social  \
# 0       ic  2021-01-04  c08724              casas sovero daniela yamilet
# 1       ic  2021-01-04  c08724              casas sovero daniela yamilet
# 2       ic  2021-01-04  c10722                 gc service & parts s.a.c.
# 3       ic  2021-01-05  c12849               lopez rosales yolanda juana
# 4       ic  2021-01-06  c11327                     palante flotas s.a.c.
# ...     ..         ...     ...                                       ...
# 576016  tg  2024-05-17  c07355  empresa de transportes sol de oro s.a.c.
# 576017  tg  2024-05-22  c07477     lubricentro virgen del rosario s.r.l.
# 576018  tg  2024-05-22  c07477     lubricentro virgen del rosario s.r.l.
# 576019  tg  2024-05-23  c07358                     gqr autopartes s.a.c.
# 576020  tg  2024-05-23  c07358                     gqr autopartes s.a.c.
#
#                                                     rubro departamento  \
# 0       ventas de partes, piezas y accesorios para veh...         lima
# 1       ventas de partes, piezas y accesorios para veh...         lima
# 2                                                     NaN         lima
# 3                                                     NaN        junin
# 4                                                     NaN         lima
# ...                                                   ...          ...
# 576016                     venta de vehículos automotores         lima
# 576017  ventas de partes, piezas y accesorios para veh...     arequipa
# 576018  ventas de partes, piezas y accesorios para veh...     arequipa
# 576019  ventas de partes, piezas y accesorios para veh...         lima
# 576020  ventas de partes, piezas y accesorios para veh...         lima
#
#               documento   articulo                         nombre_articulo  \
# 0       f001-01-0034897      48320                        focos h1 12v 55w
# 1       f001-01-0034897      48901           focos h4 12v 100x90 rallye(7)
# 2       f001-01-0034900    c-23610      filtro de aire 1° af25729 055134r1
# 3       f001-01-0034918     zd1567  pastillas de freno ceramica d1567 delt
# 4       f001-01-0034930  rp2050100               aceite sae20w50 sn racing
# ...                 ...        ...                                     ...
# 576016  f001-01-0025959  hm11r22.5               llantas himito nl118 18pr
# 576017  f001-01-0025994      t1085        trapecio del lh inf  48069-0k090
# 576018  f001-01-0025994      t1086        trapecio del rh inf  48068-0k090
# 576019  f001-01-0026008      cv-15         palier 25x23x55 c/anillo ni-214
# 576020  f001-01-0026008    to-7391                 copa de palier 23x31x34
#
#              fuente_suministro  cantidad  venta_usd  venta_pen        costo  \
# 0                        narva      50.0      51.27     185.80   134.870000
# 1                        narva     300.0     597.46    2165.20  1413.050100
# 2                mann - brasil       8.0     152.54     552.80   310.150000
# 3           wagner - pastillas       2.0      42.36     153.68    96.560000
# 4                    valvoline      90.0     861.86    3129.41  2323.670040
# ...                        ...       ...        ...        ...          ...
# 576016                 deruibo      20.0    2796.61   10425.76  7899.060000
# 576017  ito koyama - trapecios       1.0      59.92     223.68   119.090000
# 576018  ito koyama - trapecios       1.0      59.92     223.68   118.290000
# 576019   ito koyama - palieres       6.0      63.94     239.33   159.430002
# 576020   ito koyama - palieres      16.0     202.79     759.04   529.950000
#
#                              vendedor                       cobrador  \
# 0                 bayona paiva myriam            vega zúñiga enrique
# 1                 bayona paiva myriam            vega zúñiga enrique
# 2                rojas vasquez lilian                        oficina
# 3              cañas flores alan joel         cañas flores alan joel
# 4                         mostrador 4        olórtegui manrique juan
# ...                               ...                            ...
# 576016  lupaca castañeda gisela yanet  fernández monge juan fernando
# 576017        vega ganoza jose carlos   valderrama acuña luisa maria
# 576018        vega ganoza jose carlos   valderrama acuña luisa maria
# 576019                pinedo peña luz            vega zúñiga enrique
# 576020                pinedo peña luz            vega zúñiga enrique
#
#               marca  transacciones
# 0       no registro              1
# 1       no registro              1
# 2       no registro              1
# 3       no registro              1
# 4       no registro              1
# ...             ...            ...
# 576016  no registro              1
# 576017  no registro              1
# 576018  no registro              1
# 576019  no registro              1
# 576020  no registro              1
#
# [576021 rows x 18 columns]

# %%
kits
# Out:
#    Código KIT (Sin historial)  Código 1  Código 2   Código 3
# 0                   CST-007AA   CT-011U   DT-123V        NaN
# 1                   CST-008AA   CTX-145   DTX-199        NaN
# 2                   CST-009AA   CTX-166   DTX-197        NaN
# 3                    CST-011A   CTX-088   DT-124V        NaN
# 4                   CST-015AA   CTX-064   DTX-099        NaN
# 5                   CST-016AA   CTX-064  DTX-099L        NaN
# 6                   CST-018AA   CTX-071   DT-100V        NaN
# 7                   CST-019AA   CTX-062    DT-036        NaN
# 8                   CST-020AA   CTX-062   DT-036V        NaN
# 9                   CST-021AA   CTX-151   DTX-202        NaN
# 10                  CST-022AA   CTX-123   DTX-188        NaN
# 11                  CST-023AA  CTX-174A  DTX-237A        NaN
# 12                  CST-024AA  CTX-175A  DTX-238A        NaN
# 13               CKT-500AU-LB  CDX-019A   DT-611U        NaN
# 14               CKT-501AA-LB  CDX-019A  DDX-041A        NaN
# 15               CKT-506AA-LB  CTX-160A   DTX-116        NaN
# 16               CKT-507AA-LB  CTX-160A  DTX-209A        NaN
# 17               CKT-508AA-LB  CTX-170Z  DTX-232A        NaN
# 18               CKT-512AA-LB  CTX-115A    DT-628        NaN
# 19               CKT-513AA-LB  CTX-115A   DTX-146        NaN
# 20              CKT-500AU-MRK  CDX-019A   DT-611U  TKS44-25K
# 21              CKT-507AA-MRK  CTX-160A  DTX-209A  TKS58-31K
# 22              CKT-507AU-MRK  CTX-160A    DT-625  TKS58-31K
# 23              CKT-508AA-MRK  CTX-170Z  DTX-232A  TKS58-50K
# 24              CKT-510AA-MRK   CT-011U   DT-123V  TKS50-33K
# 25              CKT-511AA-MRK   CTX-088   DT-124V  TKS50-31K

# %%
ventas.describe()
# Out:
#             cantidad      venta_usd      venta_pen          costo  \
# count  576021.000000  576021.000000  576021.000000  576021.000000
# mean       23.846181     124.581396     475.438098     313.715927
# std       226.730771     336.646284    1289.009821     935.095311
# min         0.300000       0.000000       0.000000       0.180000
# 25%         2.000000      23.940000      91.490000      54.000000
# 50%         5.000000      48.830000     186.970000     111.650000
# 75%        12.000000     108.470000     413.780000     255.820000
# max     45000.000000   30254.240000  117628.490000   67296.816000
#
#        transacciones
# count       576021.0
# mean             1.0
# std              0.0
# min              1.0
# 25%              1.0
# 50%              1.0
# 75%              1.0
# max              1.0

# %%
ventas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 576021 entries, 0 to 576020
# Data columns (total 18 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   cia                576021 non-null  object
#  1   fecha              576021 non-null  object
#  2   codigo             576021 non-null  object
#  3   razon_social       576021 non-null  object
#  4   rubro              196814 non-null  object
#  5   departamento       576010 non-null  object
#  6   documento          576021 non-null  object
#  7   articulo           576021 non-null  object
#  8   nombre_articulo    576021 non-null  object
#  9   fuente_suministro  576019 non-null  object
#  10  cantidad           576021 non-null  float64
#  11  venta_usd          576021 non-null  float64
#  12  venta_pen          576021 non-null  float64
#  13  costo              576021 non-null  float64
#  14  vendedor           576021 non-null  object
#  15  cobrador           491241 non-null  object
#  16  marca              576021 non-null  object
#  17  transacciones      576021 non-null  int64
# dtypes: float64(4), int64(1), object(13)
# memory usage: 79.1+ MB

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
porcentaje_nulos = ventas.isnull().mean() * 100

plt.figure(figsize=(10, 6))
porcentaje_nulos.plot(kind='bar', color='skyblue')

plt.title('Porcentaje de valores nulos por columna', fontsize=16)
plt.xlabel('Columnas', fontsize=12)
plt.ylabel('Porcentaje de valores nulos (%)', fontsize=12)

plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
ventas.vendedor.value_counts()
# Out:
# vendedor
# saavedra cicirello jose doming      50637
# nora de la fuente gutierrez         33413
# revolledo humala paulo              30954
# osorio echevarria roger alcides     29485
# bayona paiva myriam                 27330
# escobar salinas miguel              26578
# rojas vasquez abner                 26003
# caceres julca david                 24784
# vega amouero luis carlos            22929
# valle atahuaman toribio             22678
# peña alva mariluz milagros          21172
# pinedo peña luz                     20525
# alarcon altamirano pepe             18917
# otiniano rojas carmen katia         18693
# purihuaman de la cruz carlos        17396
# meza ramirez julio                  15828
# cañas flores alan joel              14064
# gil zuñiga climaco                  13942
# huaman jara daniel                  13226
# quispe tasa william                  9516
# rojas vasquez lilian                 8983
# tarazona davila jefer                8125
# lupaca castañeda gisela yanet        7829
# ponce galindo lady skarlet           7404
# ruiz revolledo jose luis             7298
# velarde konja roberto                6400
# celis paredes julio                  4849
# gerencia oficina                     4767
# torres quiñones luis alberto         4330
# fernandez perez genesis victoria     4115
# chavez ariste fernando               4032
# escobar herrera stephanny            3884
# rojas vasquez keneth                 3787
# medina garcia manuel                 3729
# omar velarde durand                  3323
# castro elias harol armando           3016
# alarcon altamirano mayco             3009
# cavassa guzman bruno                 3007
# mostrador 4                          2999
# castañeda cisneros jose adriano      2720
# mansilla dias jimmy alfonso          2616
# coronado guerrero josue              2561
# carpio sanchez robert                2502
# ponce galindo lady rubi              2333
# guerra gentille josue                2057
# mostrador 1                          1944
# ruelas quillatupa flora luisa        1371
# bravo crisanto david esteban         1186
# vega ganoza jose carlos               924
# revatta escobar rogelio               852
# auccasi huamani thania soledad        652
# valdivia hidalgo patrick              616
# balmaceda bayona ursula               388
# mariño saccaco eric alberto           272
# bruno fernandez franz starky           65
# abdias robles sandoval                  6
# Name: count, dtype: int64

# %%
top10vendedores = ventas.vendedor.value_counts().nlargest(10)

plt.figure(figsize=(10, 6))
top10vendedores.plot(kind='bar', color='skyblue', edgecolor='black')


plt.title('Top 10 Vendedores por Número de Ventas', fontsize=16)
plt.xlabel('Vendedor', fontsize=12)
plt.ylabel('Número de Ventas', fontsize=12)


plt.xticks(rotation=45, ha='right')  
plt.tight_layout()
plt.show()

# %%
top_vendedoresxmonto =  ventas.groupby('vendedor')[['venta_usd', 'venta_pen']].sum()
top_vendedoresxmonto.sort_values(by= 'venta_pen', ascending=False, inplace=True)
top_vendedoresxmonto.head(10)
# Out:
#                                  venta_usd    venta_pen
# vendedor
# saavedra cicirello jose doming  5053445.33  19295716.33
# escobar salinas miguel          3624160.15  13836111.98
# rojas vasquez abner             3325224.55  12686539.65
# revolledo humala paulo          3022086.04  11552230.91
# huaman jara daniel              2788509.06  10665063.73
# purihuaman de la cruz carlos    2708759.31  10340355.39
# gerencia oficina                2657164.50  10177316.34
# nora de la fuente gutierrez     2641695.98  10084641.40
# alarcon altamirano pepe         2553870.73   9741773.76
# peña alva mariluz milagros      2386742.69   9099005.07

# %%
plt.figure(figsize=(10, 6))
top_vendedoresxmonto.venta_pen.head(10).plot(kind='bar', color='skyblue', edgecolor='black')


plt.title('Top 10 Vendedores por monto de ventas', fontsize=16)
plt.xlabel('Vendedor', fontsize=12)
plt.ylabel('Monto en PEN', fontsize=12)


plt.xticks(rotation=45, ha='right')  
plt.tight_layout()
plt.show()

# %%
ventas.marca.value_counts()
# Out:
# marca
# no registro    575025
# toyota            558
# mg                202
# nissan            193
# hyundai            23
# ford               17
# hino                3
# Name: count, dtype: int64

# %%
data = ventas.drop(['cia', 'codigo', 'articulo', 'marca'], axis=1)
data
# Out:
#              fecha                              razon_social  \
# 0       2021-01-04              casas sovero daniela yamilet
# 1       2021-01-04              casas sovero daniela yamilet
# 2       2021-01-04                 gc service & parts s.a.c.
# 3       2021-01-05               lopez rosales yolanda juana
# 4       2021-01-06                     palante flotas s.a.c.
# ...            ...                                       ...
# 576016  2024-05-17  empresa de transportes sol de oro s.a.c.
# 576017  2024-05-22     lubricentro virgen del rosario s.r.l.
# 576018  2024-05-22     lubricentro virgen del rosario s.r.l.
# 576019  2024-05-23                     gqr autopartes s.a.c.
# 576020  2024-05-23                     gqr autopartes s.a.c.
#
#                                                     rubro departamento  \
# 0       ventas de partes, piezas y accesorios para veh...         lima
# 1       ventas de partes, piezas y accesorios para veh...         lima
# 2                                                     NaN         lima
# 3                                                     NaN        junin
# 4                                                     NaN         lima
# ...                                                   ...          ...
# 576016                     venta de vehículos automotores         lima
# 576017  ventas de partes, piezas y accesorios para veh...     arequipa
# 576018  ventas de partes, piezas y accesorios para veh...     arequipa
# 576019  ventas de partes, piezas y accesorios para veh...         lima
# 576020  ventas de partes, piezas y accesorios para veh...         lima
#
#               documento                         nombre_articulo  \
# 0       f001-01-0034897                        focos h1 12v 55w
# 1       f001-01-0034897           focos h4 12v 100x90 rallye(7)
# 2       f001-01-0034900      filtro de aire 1° af25729 055134r1
# 3       f001-01-0034918  pastillas de freno ceramica d1567 delt
# 4       f001-01-0034930               aceite sae20w50 sn racing
# ...                 ...                                     ...
# 576016  f001-01-0025959               llantas himito nl118 18pr
# 576017  f001-01-0025994        trapecio del lh inf  48069-0k090
# 576018  f001-01-0025994        trapecio del rh inf  48068-0k090
# 576019  f001-01-0026008         palier 25x23x55 c/anillo ni-214
# 576020  f001-01-0026008                 copa de palier 23x31x34
#
#              fuente_suministro  cantidad  venta_usd  venta_pen        costo  \
# 0                        narva      50.0      51.27     185.80   134.870000
# 1                        narva     300.0     597.46    2165.20  1413.050100
# 2                mann - brasil       8.0     152.54     552.80   310.150000
# 3           wagner - pastillas       2.0      42.36     153.68    96.560000
# 4                    valvoline      90.0     861.86    3129.41  2323.670040
# ...                        ...       ...        ...        ...          ...
# 576016                 deruibo      20.0    2796.61   10425.76  7899.060000
# 576017  ito koyama - trapecios       1.0      59.92     223.68   119.090000
# 576018  ito koyama - trapecios       1.0      59.92     223.68   118.290000
# 576019   ito koyama - palieres       6.0      63.94     239.33   159.430002
# 576020   ito koyama - palieres      16.0     202.79     759.04   529.950000
#
#                              vendedor                       cobrador  \
# 0                 bayona paiva myriam            vega zúñiga enrique
# 1                 bayona paiva myriam            vega zúñiga enrique
# 2                rojas vasquez lilian                        oficina
# 3              cañas flores alan joel         cañas flores alan joel
# 4                         mostrador 4        olórtegui manrique juan
# ...                               ...                            ...
# 576016  lupaca castañeda gisela yanet  fernández monge juan fernando
# 576017        vega ganoza jose carlos   valderrama acuña luisa maria
# 576018        vega ganoza jose carlos   valderrama acuña luisa maria
# 576019                pinedo peña luz            vega zúñiga enrique
# 576020                pinedo peña luz            vega zúñiga enrique
#
#         transacciones
# 0                   1
# 1                   1
# 2                   1
# 3                   1
# 4                   1
# ...               ...
# 576016              1
# 576017              1
# 576018              1
# 576019              1
# 576020              1
#
# [576021 rows x 14 columns]

# %%
ventas.departamento.value_counts()
# Out:
# departamento
# lima             247572
# arequipa          56062
# la libertad       44984
# junin             32385
# cusco             24381
# ancash            20092
# lambayeque        19056
# apurimac          13646
# ica               13360
# puno              13126
# cajamarca         12942
# huanuco           12452
# piura              9724
# tacna              8478
# callao             8290
# ucayali            8172
# ayacucho           7598
# san martin         7252
# moquegua           4390
# pasco              3117
# loreto             2520
# huancavelica       2304
# tumbes             2049
# madre de dios      1052
# amazonas           1006
# Name: count, dtype: int64

# %%
top10departamentos = ventas.departamento.value_counts().nlargest(10)
top10departamentos.plot(kind='bar')

plt.title('Top 10 departamentos por ventas', fontsize=16)
plt.xlabel('Departamentos', fontsize=12)
plt.ylabel('Número de Ventas', fontsize=12)


plt.xticks(rotation=45, ha='right')  
plt.tight_layout()
plt.show()

# %%
ventas.transacciones.value_counts()
# Out:
# transacciones
# 1    576021
# Name: count, dtype: int64

# %%
data.drop(['transacciones'], axis=1, inplace=True)
data
# Out:
#              fecha                              razon_social  \
# 0       2021-01-04              casas sovero daniela yamilet
# 1       2021-01-04              casas sovero daniela yamilet
# 2       2021-01-04                 gc service & parts s.a.c.
# 3       2021-01-05               lopez rosales yolanda juana
# 4       2021-01-06                     palante flotas s.a.c.
# ...            ...                                       ...
# 576016  2024-05-17  empresa de transportes sol de oro s.a.c.
# 576017  2024-05-22     lubricentro virgen del rosario s.r.l.
# 576018  2024-05-22     lubricentro virgen del rosario s.r.l.
# 576019  2024-05-23                     gqr autopartes s.a.c.
# 576020  2024-05-23                     gqr autopartes s.a.c.
#
#                                                     rubro departamento  \
# 0       ventas de partes, piezas y accesorios para veh...         lima
# 1       ventas de partes, piezas y accesorios para veh...         lima
# 2                                                     NaN         lima
# 3                                                     NaN        junin
# 4                                                     NaN         lima
# ...                                                   ...          ...
# 576016                     venta de vehículos automotores         lima
# 576017  ventas de partes, piezas y accesorios para veh...     arequipa
# 576018  ventas de partes, piezas y accesorios para veh...     arequipa
# 576019  ventas de partes, piezas y accesorios para veh...         lima
# 576020  ventas de partes, piezas y accesorios para veh...         lima
#
#               documento                         nombre_articulo  \
# 0       f001-01-0034897                        focos h1 12v 55w
# 1       f001-01-0034897           focos h4 12v 100x90 rallye(7)
# 2       f001-01-0034900      filtro de aire 1° af25729 055134r1
# 3       f001-01-0034918  pastillas de freno ceramica d1567 delt
# 4       f001-01-0034930               aceite sae20w50 sn racing
# ...                 ...                                     ...
# 576016  f001-01-0025959               llantas himito nl118 18pr
# 576017  f001-01-0025994        trapecio del lh inf  48069-0k090
# 576018  f001-01-0025994        trapecio del rh inf  48068-0k090
# 576019  f001-01-0026008         palier 25x23x55 c/anillo ni-214
# 576020  f001-01-0026008                 copa de palier 23x31x34
#
#              fuente_suministro  cantidad  venta_usd  venta_pen        costo  \
# 0                        narva      50.0      51.27     185.80   134.870000
# 1                        narva     300.0     597.46    2165.20  1413.050100
# 2                mann - brasil       8.0     152.54     552.80   310.150000
# 3           wagner - pastillas       2.0      42.36     153.68    96.560000
# 4                    valvoline      90.0     861.86    3129.41  2323.670040
# ...                        ...       ...        ...        ...          ...
# 576016                 deruibo      20.0    2796.61   10425.76  7899.060000
# 576017  ito koyama - trapecios       1.0      59.92     223.68   119.090000
# 576018  ito koyama - trapecios       1.0      59.92     223.68   118.290000
# 576019   ito koyama - palieres       6.0      63.94     239.33   159.430002
# 576020   ito koyama - palieres      16.0     202.79     759.04   529.950000
#
#                              vendedor                       cobrador
# 0                 bayona paiva myriam            vega zúñiga enrique
# 1                 bayona paiva myriam            vega zúñiga enrique
# 2                rojas vasquez lilian                        oficina
# 3              cañas flores alan joel         cañas flores alan joel
# 4                         mostrador 4        olórtegui manrique juan
# ...                               ...                            ...
# 576016  lupaca castañeda gisela yanet  fernández monge juan fernando
# 576017        vega ganoza jose carlos   valderrama acuña luisa maria
# 576018        vega ganoza jose carlos   valderrama acuña luisa maria
# 576019                pinedo peña luz            vega zúñiga enrique
# 576020                pinedo peña luz            vega zúñiga enrique
#
# [576021 rows x 13 columns]

# %%
ventas.codigo.value_counts().nlargest(15)
# Out:
# codigo
# c09110    6294
# c13026    3751
# c05365    3743
# c10888    3564
# c14751    3450
# c02422    3173
# c10907    2931
# c01172    2624
# c15013    2616
# c00584    2528
# c08854    2430
# c09489    2305
# c10577    2270
# c08958    2137
# c13414    2120
# Name: count, dtype: int64

# %%
ventas.articulo.value_counts().nlargest(15)
# Out:
# articulo
# wk-1060/1    3644
# ef-1509      3256
# fc-2904      2925
# a-1331-s     2692
# 48881        2622
# wk-1040      2462
# 17916        2387
# ef-15130     2368
# c-1011       2304
# c-1314       2207
# 884544       2141
# a-5541-s     2121
# fc-1807      2051
# 48901        2029
# ef-1003      1939
# Name: count, dtype: int64

# %%
ventas.nombre_articulo.value_counts().nlargest(15)
# Out:
# nombre_articulo
# filtro sep de agua(6)lfwp9000 fs19532        3644
# focos 1034 2 cont p21/5w                     3366
# amortiguador del rh                          3292
# amortiguador del lh                          3287
# filtro de petroleo(50)8-98162-897-0          3256
# filtro de petroleo(25)1457434310             2925
# focos 93 1 cont 1141 p21w                    2843
# kit de filtros(1)1º2º a-1325+a-1330          2692
# amortiguador post rh lh                      2628
# focos h4 60x55w p43t-38                      2622
# filtro sep de agua(6)ps6643 fco553a          2462
# filtro de aceite(50)fco515 lf3007 lf3537     2398
# filtro de petroleo(25)8-98092481-1           2368
# focos 158 lagri mediana w5w                  2359
# aceite sae5w30 sn synthetic glx1.25gl 5/4    2276
# Name: count, dtype: int64

# %%
data['fecha'] = pd.to_datetime(data['fecha'], errors='coerce')

data['mes'] = data['fecha'].dt.to_period('M')

ventas_por_mes = data.groupby('mes')[['venta_usd', 'venta_pen']].sum()

ventas_por_mes
# Out:
#           venta_usd   venta_pen
# mes
# 2021-01  1933511.61  7014900.01
# 2021-02  1256231.07  4582610.19
# 2021-03  1651111.00  6131916.76
# 2021-04  1559317.64  5795570.31
# 2021-05  1678123.03  6330120.18
# 2021-06  1452193.94  5702903.87
# 2021-07  1512137.50  5973909.53
# 2021-08  2084636.60  8523638.47
# 2021-09  1876057.54  7713067.69
# 2021-10  1822384.81  7301849.26
# 2021-11  1650965.93  6646437.24
# 2021-12  1842618.66  7451412.71
# 2022-01  1768020.10  6867666.34
# 2022-02  1595318.38  6044248.81
# 2022-03  1779407.39  6656935.98
# 2022-04  1575826.98  5944487.70
# 2022-05  1985215.13  7418069.82
# 2022-06  1831379.15  6875582.90
# 2022-07  1626853.74  6357540.21
# 2022-08  2245583.33  8689803.50
# 2022-09  2014224.70  7878536.77
# 2022-10  1780954.15  7092459.87
# 2022-11  1811159.29  7007152.79
# 2022-12  1427073.98  5470909.12
# 2023-01  1583579.49  6081726.56
# 2023-02  1770174.15  6795807.66
# 2023-03  1869015.73  7061381.01
# 2023-04  1822136.44  6859046.89
# 2023-05  1908342.28  7041748.25
# 2023-06  1539070.64  5615949.34
# 2023-07  1791780.23  6450358.73
# 2023-08  2032882.43  7522065.82
# 2023-09  1717484.65  6428772.87
# 2023-10  1693528.68  6521079.11
# 2023-11  1525776.39  5736863.84
# 2023-12  1737642.22  6487222.85
# 2024-01  1900732.14  7128205.81
# 2024-02  1793183.57  6863850.28
# 2024-03  1742815.15  6472918.45
# 2024-04  1762465.05  6553461.22
# 2024-05  1810585.45  6770140.10

# %%
top_10_meses = ventas_por_mes.sort_values(by='venta_pen', ascending=False).head(10)

plt.figure(figsize=(10, 6))
top_10_meses['venta_pen'].plot(kind='bar', color='skyblue', edgecolor='black')

plt.title('Top 10 Meses con Más Ventas (PEN)', fontsize=16)
plt.xlabel('Mes', fontsize=12)
plt.ylabel('Ventas en PEN', fontsize=12)

# Mostrar el gráfico
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
departamento_dict = {
    'lima': 1,
    'arequipa': 2,
    'la libertad': 3,
    'junin': 4,
    'cusco': 5,
    'ancash': 6,
    'lambayeque': 7,
    'apurimac': 8,
    'ica': 9,
    'puno': 10,
    'cajamarca': 11,
    'huanuco': 12,
    'piura': 13,
    'tacna': 14,
    'callao': 15,
    'ucayali': 16,
    'ayacucho': 17,
    'san martin': 18,
    'moquegua': 19,
    'pasco': 20,
    'loreto': 21,
    'huancavelica': 22,
    'tumbes': 23,
    'madre de dios': 24,
    'amazonas': 25
}

# %%
data['departamento'] = data['departamento'].str.lower()  
data['departamento_num'] = data['departamento'].map(departamento_dict)
data
# Out:
#             fecha                              razon_social  \
# 0      2021-01-04              casas sovero daniela yamilet
# 1      2021-01-04              casas sovero daniela yamilet
# 2      2021-01-04                 gc service & parts s.a.c.
# 3      2021-01-05               lopez rosales yolanda juana
# 4      2021-01-06                     palante flotas s.a.c.
# ...           ...                                       ...
# 576016 2024-05-17  empresa de transportes sol de oro s.a.c.
# 576017 2024-05-22     lubricentro virgen del rosario s.r.l.
# 576018 2024-05-22     lubricentro virgen del rosario s.r.l.
# 576019 2024-05-23                     gqr autopartes s.a.c.
# 576020 2024-05-23                     gqr autopartes s.a.c.
#
#                                                     rubro departamento  \
# 0       ventas de partes, piezas y accesorios para veh...         lima
# 1       ventas de partes, piezas y accesorios para veh...         lima
# 2                                                     NaN         lima
# 3                                                     NaN        junin
# 4                                                     NaN         lima
# ...                                                   ...          ...
# 576016                     venta de vehículos automotores         lima
# 576017  ventas de partes, piezas y accesorios para veh...     arequipa
# 576018  ventas de partes, piezas y accesorios para veh...     arequipa
# 576019  ventas de partes, piezas y accesorios para veh...         lima
# 576020  ventas de partes, piezas y accesorios para veh...         lima
#
#               documento                         nombre_articulo  \
# 0       f001-01-0034897                        focos h1 12v 55w
# 1       f001-01-0034897           focos h4 12v 100x90 rallye(7)
# 2       f001-01-0034900      filtro de aire 1° af25729 055134r1
# 3       f001-01-0034918  pastillas de freno ceramica d1567 delt
# 4       f001-01-0034930               aceite sae20w50 sn racing
# ...                 ...                                     ...
# 576016  f001-01-0025959               llantas himito nl118 18pr
# 576017  f001-01-0025994        trapecio del lh inf  48069-0k090
# 576018  f001-01-0025994        trapecio del rh inf  48068-0k090
# 576019  f001-01-0026008         palier 25x23x55 c/anillo ni-214
# 576020  f001-01-0026008                 copa de palier 23x31x34
#
#              fuente_suministro  cantidad  venta_usd  venta_pen        costo  \
# 0                        narva      50.0      51.27     185.80   134.870000
# 1                        narva     300.0     597.46    2165.20  1413.050100
# 2                mann - brasil       8.0     152.54     552.80   310.150000
# 3           wagner - pastillas       2.0      42.36     153.68    96.560000
# 4                    valvoline      90.0     861.86    3129.41  2323.670040
# ...                        ...       ...        ...        ...          ...
# 576016                 deruibo      20.0    2796.61   10425.76  7899.060000
# 576017  ito koyama - trapecios       1.0      59.92     223.68   119.090000
# 576018  ito koyama - trapecios       1.0      59.92     223.68   118.290000
# 576019   ito koyama - palieres       6.0      63.94     239.33   159.430002
# 576020   ito koyama - palieres      16.0     202.79     759.04   529.950000
#
#                              vendedor                       cobrador      mes  \
# 0                 bayona paiva myriam            vega zúñiga enrique  2021-01
# 1                 bayona paiva myriam            vega zúñiga enrique  2021-01
# 2                rojas vasquez lilian                        oficina  2021-01
# 3              cañas flores alan joel         cañas flores alan joel  2021-01
# 4                         mostrador 4        olórtegui manrique juan  2021-01
# ...                               ...                            ...      ...
# 576016  lupaca castañeda gisela yanet  fernández monge juan fernando  2024-05
# 576017        vega ganoza jose carlos   valderrama acuña luisa maria  2024-05
# 576018        vega ganoza jose carlos   valderrama acuña luisa maria  2024-05
# 576019                pinedo peña luz            vega zúñiga enrique  2024-05
# 576020                pinedo peña luz            vega zúñiga enrique  2024-05
#
#         departamento_num
# 0                    1.0
# 1                    1.0
# 2                    1.0
# 3                    4.0
# 4                    1.0
# ...                  ...
# 576016               1.0
# 576017               2.0
# 576018               2.0
# 576019               1.0
# 576020               1.0
#
# [576021 rows x 15 columns]

# %%
data.drop(['departamento'], axis=1, inplace=True)
data
# Out:
#             fecha                              razon_social  \
# 0      2021-01-04              casas sovero daniela yamilet
# 1      2021-01-04              casas sovero daniela yamilet
# 2      2021-01-04                 gc service & parts s.a.c.
# 3      2021-01-05               lopez rosales yolanda juana
# 4      2021-01-06                     palante flotas s.a.c.
# ...           ...                                       ...
# 576016 2024-05-17  empresa de transportes sol de oro s.a.c.
# 576017 2024-05-22     lubricentro virgen del rosario s.r.l.
# 576018 2024-05-22     lubricentro virgen del rosario s.r.l.
# 576019 2024-05-23                     gqr autopartes s.a.c.
# 576020 2024-05-23                     gqr autopartes s.a.c.
#
#                                                     rubro        documento  \
# 0       ventas de partes, piezas y accesorios para veh...  f001-01-0034897
# 1       ventas de partes, piezas y accesorios para veh...  f001-01-0034897
# 2                                                     NaN  f001-01-0034900
# 3                                                     NaN  f001-01-0034918
# 4                                                     NaN  f001-01-0034930
# ...                                                   ...              ...
# 576016                     venta de vehículos automotores  f001-01-0025959
# 576017  ventas de partes, piezas y accesorios para veh...  f001-01-0025994
# 576018  ventas de partes, piezas y accesorios para veh...  f001-01-0025994
# 576019  ventas de partes, piezas y accesorios para veh...  f001-01-0026008
# 576020  ventas de partes, piezas y accesorios para veh...  f001-01-0026008
#
#                                nombre_articulo       fuente_suministro  \
# 0                             focos h1 12v 55w                   narva
# 1                focos h4 12v 100x90 rallye(7)                   narva
# 2           filtro de aire 1° af25729 055134r1           mann - brasil
# 3       pastillas de freno ceramica d1567 delt      wagner - pastillas
# 4                    aceite sae20w50 sn racing               valvoline
# ...                                        ...                     ...
# 576016               llantas himito nl118 18pr                 deruibo
# 576017        trapecio del lh inf  48069-0k090  ito koyama - trapecios
# 576018        trapecio del rh inf  48068-0k090  ito koyama - trapecios
# 576019         palier 25x23x55 c/anillo ni-214   ito koyama - palieres
# 576020                 copa de palier 23x31x34   ito koyama - palieres
#
#         cantidad  venta_usd  venta_pen        costo  \
# 0           50.0      51.27     185.80   134.870000
# 1          300.0     597.46    2165.20  1413.050100
# 2            8.0     152.54     552.80   310.150000
# 3            2.0      42.36     153.68    96.560000
# 4           90.0     861.86    3129.41  2323.670040
# ...          ...        ...        ...          ...
# 576016      20.0    2796.61   10425.76  7899.060000
# 576017       1.0      59.92     223.68   119.090000
# 576018       1.0      59.92     223.68   118.290000
# 576019       6.0      63.94     239.33   159.430002
# 576020      16.0     202.79     759.04   529.950000
#
#                              vendedor                       cobrador      mes  \
# 0                 bayona paiva myriam            vega zúñiga enrique  2021-01
# 1                 bayona paiva myriam            vega zúñiga enrique  2021-01
# 2                rojas vasquez lilian                        oficina  2021-01
# 3              cañas flores alan joel         cañas flores alan joel  2021-01
# 4                         mostrador 4        olórtegui manrique juan  2021-01
# ...                               ...                            ...      ...
# 576016  lupaca castañeda gisela yanet  fernández monge juan fernando  2024-05
# 576017        vega ganoza jose carlos   valderrama acuña luisa maria  2024-05
# 576018        vega ganoza jose carlos   valderrama acuña luisa maria  2024-05
# 576019                pinedo peña luz            vega zúñiga enrique  2024-05
# 576020                pinedo peña luz            vega zúñiga enrique  2024-05
#
#         departamento_num
# 0                    1.0
# 1                    1.0
# 2                    1.0
# 3                    4.0
# 4                    1.0
# ...                  ...
# 576016               1.0
# 576017               2.0
# 576018               2.0
# 576019               1.0
# 576020               1.0
#
# [576021 rows x 14 columns]

# %%
ventas.rubro.value_counts()
# Out:
# rubro
# ventas de partes, piezas y accesorios para vehículos automotores                                        143031
# venta al por mayor de combustibles sólidos, líquidos y gaseosos y  productos conexos                      9671
# venta al por menor de combustibles para vehículos automotores en comercios especializados                 5994
# venta al por mayor no especializada                                                                       5590
# alquiler y arrendamiento de vehículos automotores                                                         4412
# otras actividades de servicios personales n.c.p.                                                          4306
# transporte  de carga por carretera.                                                                       3629
# transporte de carga por carretera                                                                         3266
# mantenimiento y reparación de vehículos automotores                                                       3150
# venta de vehículos automotores                                                                            2658
# venta partes, piezas, accesorios.                                                                         1878
# venta, mantenimiento y reparación de motocicletas y de sus partes, piezas y accesorios.                   1174
# otras actividades de venta al por menor en comercios no especializados                                    1059
# otras actividades de transporte por vía terrestre                                                          851
# ventas de partes, piezas y accesorios para vehículos                                                       774
# alquiler y arrendamiento de otros tipos de maquinaria, equipo y bienes tangibles                           747
# venta al por menor de otros productos nuevos en comercios especializados                                   746
# vta. min. articulos de ferreteria.                                                                         741
# venta al por mayor a cambio de una retribución o por contrata                                              405
# vta. min. en almacenes no especializ.                                                                      399
# construcción de edificios                                                                                  396
# otras actividades profesionales, científicas y técnicas n.c.p.                                             311
# venta al por menor de equipo de deporte en comercios especializados                                        273
# otras actividades de venta al por menor no realizadas en comercios, puestos de venta o mercados            273
# venta al por mayor de otros tipos de maquinaria y equipo                                                   212
# actividades jurídicas                                                                                      208
# vta. may. de otros productos.                                                                              134
# venta al por mayor de equipo, partes y piezas electrónicos y de telecomunicaciones                          95
# venta al por mayor de alimentos, bebidas y tabaco.                                                          68
# venta al por menor de artículos de ferretería, pinturas y productos de vidrio en comercios especiali        52
# actividades de contabilidad, teneduría de libros y auditoría; consultoría fiscal                            51
# actividades de consultoría de gestión                                                                       49
# reparación de maquinaria                                                                                    40
# venta al por menor de otros productos en puestos de venta y mercados                                        35
# cultivo de uva                                                                                              31
# construcción de otras obras de ingeniería civil                                                             30
# vta. al por mayor de combustibles.                                                                          28
# fabricación de partes, piezas y accesorios para vehículos de automotores                                    23
# vta.  may. a cambio de una retribucion.                                                                      7
# otras actividades deportivas                                                                                 7
# mantenimiento y reparac. vehiculos.                                                                          6
# venta al por mayor de maquinaria, equipo y materiales agropecuarios                                          2
# venta al por menor de ordenadores, equipo periférico, programas informáticos y equipo de telecomunic         1
# actividades de médicos y odontólogos                                                                         1
# Name: count, dtype: int64

# %%
data.drop(['rubro','documento'],axis=1, inplace=True)

# %%
data.razon_social.value_counts().nlargest(20)
# Out:
# razon_social
# filmarg s.a.c.                                    6294
# antachoque espinoza ernesto alonso                3751
# repuestos ccori motor's e.i.r.l.                  3743
# lubrimaq e.i.r.l.                                 3564
# brama transp y comerc. eirl.                      3450
# transportes angel ibarcena s.a.c.                 3173
# inversiones el amortiguador e.i.r.l.              2931
# filtros san jorge sac                             2616
# benites marquina, leyter michael                  2555
# rivera collazos leonardo                          2528
# valdiviezo import e.i.r.l.                        2430
# home filter eirl                                  2305
# ore quispe aristedes                              2270
# ln lima import s.a.c.                             2137
# repuestos urbina e.i.r.l.                         2120
# movilcar srl                                      2091
# sanchez gonzales carmen rosa                      2082
# jofran peru s.a.c.                                1979
# ccori motor´s soluciones automotrices e.i.r.l.    1897
# mamani mendoza, jorge rene                        1799
# Name: count, dtype: int64

# %%
data
# Out:
#             fecha                              razon_social  \
# 0      2021-01-04              casas sovero daniela yamilet
# 1      2021-01-04              casas sovero daniela yamilet
# 2      2021-01-04                 gc service & parts s.a.c.
# 3      2021-01-05               lopez rosales yolanda juana
# 4      2021-01-06                     palante flotas s.a.c.
# ...           ...                                       ...
# 576016 2024-05-17  empresa de transportes sol de oro s.a.c.
# 576017 2024-05-22     lubricentro virgen del rosario s.r.l.
# 576018 2024-05-22     lubricentro virgen del rosario s.r.l.
# 576019 2024-05-23                     gqr autopartes s.a.c.
# 576020 2024-05-23                     gqr autopartes s.a.c.
#
#                                nombre_articulo       fuente_suministro  \
# 0                             focos h1 12v 55w                   narva
# 1                focos h4 12v 100x90 rallye(7)                   narva
# 2           filtro de aire 1° af25729 055134r1           mann - brasil
# 3       pastillas de freno ceramica d1567 delt      wagner - pastillas
# 4                    aceite sae20w50 sn racing               valvoline
# ...                                        ...                     ...
# 576016               llantas himito nl118 18pr                 deruibo
# 576017        trapecio del lh inf  48069-0k090  ito koyama - trapecios
# 576018        trapecio del rh inf  48068-0k090  ito koyama - trapecios
# 576019         palier 25x23x55 c/anillo ni-214   ito koyama - palieres
# 576020                 copa de palier 23x31x34   ito koyama - palieres
#
#         cantidad  venta_usd  venta_pen        costo  \
# 0           50.0      51.27     185.80   134.870000
# 1          300.0     597.46    2165.20  1413.050100
# 2            8.0     152.54     552.80   310.150000
# 3            2.0      42.36     153.68    96.560000
# 4           90.0     861.86    3129.41  2323.670040
# ...          ...        ...        ...          ...
# 576016      20.0    2796.61   10425.76  7899.060000
# 576017       1.0      59.92     223.68   119.090000
# 576018       1.0      59.92     223.68   118.290000
# 576019       6.0      63.94     239.33   159.430002
# 576020      16.0     202.79     759.04   529.950000
#
#                              vendedor                       cobrador      mes  \
# 0                 bayona paiva myriam            vega zúñiga enrique  2021-01
# 1                 bayona paiva myriam            vega zúñiga enrique  2021-01
# 2                rojas vasquez lilian                        oficina  2021-01
# 3              cañas flores alan joel         cañas flores alan joel  2021-01
# 4                         mostrador 4        olórtegui manrique juan  2021-01
# ...                               ...                            ...      ...
# 576016  lupaca castañeda gisela yanet  fernández monge juan fernando  2024-05
# 576017        vega ganoza jose carlos   valderrama acuña luisa maria  2024-05
# 576018        vega ganoza jose carlos   valderrama acuña luisa maria  2024-05
# 576019                pinedo peña luz            vega zúñiga enrique  2024-05
# 576020                pinedo peña luz            vega zúñiga enrique  2024-05
#
#         departamento_num
# 0                    1.0
# 1                    1.0
# 2                    1.0
# 3                    4.0
# 4                    1.0
# ...                  ...
# 576016               1.0
# 576017               2.0
# 576018               2.0
# 576019               1.0
# 576020               1.0
#
# [576021 rows x 12 columns]

# %%
data.fuente_suministro.nunique(), data.cobrador.nunique(), data.vendedor.nunique(), data.nombre_articulo.nunique(), data.razon_social.nunique()
# Out:
# (103, 53, 56, 5997, 5149)

# %%
data.cobrador.isnull().sum()
# Out:
# np.int64(84780)

# %%
moda = data.cobrador.mode()[0]
moda
# Out:
# 'olórtegui manrique juan'

# %%
data.cobrador.fillna(moda, inplace=True)
# Out:
# /tmp/ipykernel_5083/1551050380.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data.cobrador.fillna(moda, inplace=True)

# %%
vendedores_list = top_vendedoresxmonto.index
vendedores_list
# Out:
# Index(['saavedra cicirello jose doming', 'escobar salinas miguel',
#        'rojas vasquez abner', 'revolledo humala paulo', 'huaman jara daniel',
#        'purihuaman de la cruz carlos', 'gerencia oficina',
#        'nora de la fuente gutierrez', 'alarcon altamirano pepe',
#        'peña alva mariluz milagros', 'vega amouero luis carlos',
#        'caceres julca david', 'bayona paiva myriam', 'valle atahuaman toribio',
#        'otiniano rojas carmen katia', 'cavassa guzman bruno',
#        'tarazona davila jefer', 'osorio echevarria roger alcides',
#        'gil zuñiga climaco', 'meza ramirez julio', 'cañas flores alan joel',
#        'lupaca castañeda gisela yanet', 'omar velarde durand',
#        'pinedo peña luz', 'ruiz revolledo jose luis',
#        'castañeda cisneros jose adriano', 'velarde konja roberto',
#        'rojas vasquez lilian', 'ponce galindo lady skarlet', 'mostrador 4',
#        'mansilla dias jimmy alfonso', 'quispe tasa william',
#        'celis paredes julio', 'torres quiñones luis alberto',
#        'carpio sanchez robert', 'mostrador 1', 'rojas vasquez keneth',
#        'escobar herrera stephanny', 'castro elias harol armando',
#        'coronado guerrero josue', 'chavez ariste fernando',
#        'ponce galindo lady rubi', 'alarcon altamirano mayco',
#        'fernandez perez genesis victoria', 'medina garcia manuel',
#        'ruelas quillatupa flora luisa', 'guerra gentille josue',
#        'bravo crisanto david esteban', 'auccasi huamani thania soledad',
#        'vega ganoza jose carlos', 'revatta escobar rogelio',
#        'balmaceda bayona ursula', 'valdivia hidalgo patrick',
#        'mariño saccaco eric alberto', 'bruno fernandez franz starky',
#        'abdias robles sandoval'],
#       dtype='object', name='vendedor')

# %%
top_vendedoresxmonto.venta_pen.head(35).sum()/top_vendedoresxmonto.venta_pen.sum()
# Out:
# np.float64(0.940324673092437)

# %%
dict_vendedores = {vendedor: i+1 if i < 35 else 0 for i, vendedor in enumerate(vendedores_list)}
dict_vendedores
# Out:
# {'saavedra cicirello jose doming': 1,
#  'escobar salinas miguel': 2,
#  'rojas vasquez abner': 3,
#  'revolledo humala paulo': 4,
#  'huaman jara daniel': 5,
#  'purihuaman de la cruz carlos': 6,
#  'gerencia oficina': 7,
#  'nora de la fuente gutierrez': 8,
#  'alarcon altamirano pepe': 9,
#  'peña alva mariluz milagros': 10,
#  'vega amouero luis carlos': 11,
#  'caceres julca david': 12,
#  'bayona paiva myriam': 13,
#  'valle atahuaman toribio': 14,
#  'otiniano rojas carmen katia': 15,
#  'cavassa guzman bruno': 16,
#  'tarazona davila jefer': 17,
#  'osorio echevarria roger alcides': 18,
#  'gil zuñiga climaco': 19,
#  'meza ramirez julio': 20,
#  'cañas flores alan joel': 21,
#  'lupaca castañeda gisela yanet': 22,
#  'omar velarde durand': 23,
#  'pinedo peña luz': 24,
#  'ruiz revolledo jose luis': 25,
#  'castañeda cisneros jose adriano': 26,
#  'velarde konja roberto': 27,
#  'rojas vasquez lilian': 28,
#  'ponce galindo lady skarlet': 29,
#  'mostrador 4': 30,
#  'mansilla dias jimmy alfonso': 31,
#  'quispe tasa william': 32,
#  'celis paredes julio': 33,
#  'torres quiñones luis alberto': 34,
#  'carpio sanchez robert': 35,
#  'mostrador 1': 0,
#  'rojas vasquez keneth': 0,
#  'escobar herrera stephanny': 0,
#  'castro elias harol armando': 0,
#  'coronado guerrero josue': 0,
#  'chavez ariste fernando': 0,
#  'ponce galindo lady rubi': 0,
#  'alarcon altamirano mayco': 0,
#  'fernandez perez genesis victoria': 0,
#  'medina garcia manuel': 0,
#  'ruelas quillatupa flora luisa': 0,
#  'guerra gentille josue': 0,
#  'bravo crisanto david esteban': 0,
#  'auccasi huamani thania soledad': 0,
#  'vega ganoza jose carlos': 0,
#  'revatta escobar rogelio': 0,
#  'balmaceda bayona ursula': 0,
#  'valdivia hidalgo patrick': 0,
#  'mariño saccaco eric alberto': 0,
#  'bruno fernandez franz starky': 0,
#  'abdias robles sandoval': 0}

# %%
data['cod_vendedor'] = data.vendedor.map(dict_vendedores)
data
# Out:
#             fecha                              razon_social  \
# 0      2021-01-04              casas sovero daniela yamilet
# 1      2021-01-04              casas sovero daniela yamilet
# 2      2021-01-04                 gc service & parts s.a.c.
# 3      2021-01-05               lopez rosales yolanda juana
# 4      2021-01-06                     palante flotas s.a.c.
# ...           ...                                       ...
# 576016 2024-05-17  empresa de transportes sol de oro s.a.c.
# 576017 2024-05-22     lubricentro virgen del rosario s.r.l.
# 576018 2024-05-22     lubricentro virgen del rosario s.r.l.
# 576019 2024-05-23                     gqr autopartes s.a.c.
# 576020 2024-05-23                     gqr autopartes s.a.c.
#
#                                nombre_articulo       fuente_suministro  \
# 0                             focos h1 12v 55w                   narva
# 1                focos h4 12v 100x90 rallye(7)                   narva
# 2           filtro de aire 1° af25729 055134r1           mann - brasil
# 3       pastillas de freno ceramica d1567 delt      wagner - pastillas
# 4                    aceite sae20w50 sn racing               valvoline
# ...                                        ...                     ...
# 576016               llantas himito nl118 18pr                 deruibo
# 576017        trapecio del lh inf  48069-0k090  ito koyama - trapecios
# 576018        trapecio del rh inf  48068-0k090  ito koyama - trapecios
# 576019         palier 25x23x55 c/anillo ni-214   ito koyama - palieres
# 576020                 copa de palier 23x31x34   ito koyama - palieres
#
#         cantidad  venta_usd  venta_pen        costo  \
# 0           50.0      51.27     185.80   134.870000
# 1          300.0     597.46    2165.20  1413.050100
# 2            8.0     152.54     552.80   310.150000
# 3            2.0      42.36     153.68    96.560000
# 4           90.0     861.86    3129.41  2323.670040
# ...          ...        ...        ...          ...
# 576016      20.0    2796.61   10425.76  7899.060000
# 576017       1.0      59.92     223.68   119.090000
# 576018       1.0      59.92     223.68   118.290000
# 576019       6.0      63.94     239.33   159.430002
# 576020      16.0     202.79     759.04   529.950000
#
#                              vendedor                       cobrador      mes  \
# 0                 bayona paiva myriam            vega zúñiga enrique  2021-01
# 1                 bayona paiva myriam            vega zúñiga enrique  2021-01
# 2                rojas vasquez lilian                        oficina  2021-01
# 3              cañas flores alan joel         cañas flores alan joel  2021-01
# 4                         mostrador 4        olórtegui manrique juan  2021-01
# ...                               ...                            ...      ...
# 576016  lupaca castañeda gisela yanet  fernández monge juan fernando  2024-05
# 576017        vega ganoza jose carlos   valderrama acuña luisa maria  2024-05
# 576018        vega ganoza jose carlos   valderrama acuña luisa maria  2024-05
# 576019                pinedo peña luz            vega zúñiga enrique  2024-05
# 576020                pinedo peña luz            vega zúñiga enrique  2024-05
#
#         departamento_num  cod_vendedor
# 0                    1.0            13
# 1                    1.0            13
# 2                    1.0            28
# 3                    4.0            21
# 4                    1.0            30
# ...                  ...           ...
# 576016               1.0            22
# 576017               2.0             0
# 576018               2.0             0
# 576019               1.0            24
# 576020               1.0            24
#
# [576021 rows x 13 columns]

# %%
data.drop(['vendedor'], axis=1, inplace=True)
data
# Out:
#             fecha                              razon_social  \
# 0      2021-01-04              casas sovero daniela yamilet
# 1      2021-01-04              casas sovero daniela yamilet
# 2      2021-01-04                 gc service & parts s.a.c.
# 3      2021-01-05               lopez rosales yolanda juana
# 4      2021-01-06                     palante flotas s.a.c.
# ...           ...                                       ...
# 576016 2024-05-17  empresa de transportes sol de oro s.a.c.
# 576017 2024-05-22     lubricentro virgen del rosario s.r.l.
# 576018 2024-05-22     lubricentro virgen del rosario s.r.l.
# 576019 2024-05-23                     gqr autopartes s.a.c.
# 576020 2024-05-23                     gqr autopartes s.a.c.
#
#                                nombre_articulo       fuente_suministro  \
# 0                             focos h1 12v 55w                   narva
# 1                focos h4 12v 100x90 rallye(7)                   narva
# 2           filtro de aire 1° af25729 055134r1           mann - brasil
# 3       pastillas de freno ceramica d1567 delt      wagner - pastillas
# 4                    aceite sae20w50 sn racing               valvoline
# ...                                        ...                     ...
# 576016               llantas himito nl118 18pr                 deruibo
# 576017        trapecio del lh inf  48069-0k090  ito koyama - trapecios
# 576018        trapecio del rh inf  48068-0k090  ito koyama - trapecios
# 576019         palier 25x23x55 c/anillo ni-214   ito koyama - palieres
# 576020                 copa de palier 23x31x34   ito koyama - palieres
#
#         cantidad  venta_usd  venta_pen        costo  \
# 0           50.0      51.27     185.80   134.870000
# 1          300.0     597.46    2165.20  1413.050100
# 2            8.0     152.54     552.80   310.150000
# 3            2.0      42.36     153.68    96.560000
# 4           90.0     861.86    3129.41  2323.670040
# ...          ...        ...        ...          ...
# 576016      20.0    2796.61   10425.76  7899.060000
# 576017       1.0      59.92     223.68   119.090000
# 576018       1.0      59.92     223.68   118.290000
# 576019       6.0      63.94     239.33   159.430002
# 576020      16.0     202.79     759.04   529.950000
#
#                              cobrador      mes  departamento_num  cod_vendedor
# 0                 vega zúñiga enrique  2021-01               1.0            13
# 1                 vega zúñiga enrique  2021-01               1.0            13
# 2                             oficina  2021-01               1.0            28
# 3              cañas flores alan joel  2021-01               4.0            21
# 4             olórtegui manrique juan  2021-01               1.0            30
# ...                               ...      ...               ...           ...
# 576016  fernández monge juan fernando  2024-05               1.0            22
# 576017   valderrama acuña luisa maria  2024-05               2.0             0
# 576018   valderrama acuña luisa maria  2024-05               2.0             0
# 576019            vega zúñiga enrique  2024-05               1.0            24
# 576020            vega zúñiga enrique  2024-05               1.0            24
#
# [576021 rows x 12 columns]

# %%
data.nombre_articulo.value_counts().head(10)
# Out:
# nombre_articulo
# filtro sep de agua(6)lfwp9000 fs19532    3644
# focos 1034 2 cont p21/5w                 3366
# amortiguador del rh                      3292
# amortiguador del lh                      3287
# filtro de petroleo(50)8-98162-897-0      3256
# filtro de petroleo(25)1457434310         2925
# focos 93 1 cont 1141 p21w                2843
# kit de filtros(1)1º2º a-1325+a-1330      2692
# amortiguador post rh lh                  2628
# focos h4 60x55w p43t-38                  2622
# Name: count, dtype: int64

# %%
data.nombre_articulo.value_counts().head(20).sum()/data.nombre_articulo.value_counts().sum()
# Out:
# np.float64(0.0926320394568948)

# %%
data.razon_social.value_counts().head(10)
# Out:
# razon_social
# filmarg s.a.c.                          6294
# antachoque espinoza ernesto alonso      3751
# repuestos ccori motor's e.i.r.l.        3743
# lubrimaq e.i.r.l.                       3564
# brama transp y comerc. eirl.            3450
# transportes angel ibarcena s.a.c.       3173
# inversiones el amortiguador e.i.r.l.    2931
# filtros san jorge sac                   2616
# benites marquina, leyter michael        2555
# rivera collazos leonardo                2528
# Name: count, dtype: int64

# %%
data.razon_social.value_counts().head(20).sum()/data.razon_social.value_counts().sum()
# Out:
# np.float64(0.09672390416321627)

# %%
razon_social_list = data.razon_social.value_counts().index
razon_social_list
# Out:
# Index(['filmarg s.a.c.', 'antachoque espinoza ernesto alonso',
#        'repuestos ccori motor's e.i.r.l.', 'lubrimaq e.i.r.l.',
#        'brama transp y comerc. eirl.', 'transportes angel ibarcena s.a.c.',
#        'inversiones el amortiguador e.i.r.l.', 'filtros san jorge sac',
#        'benites marquina, leyter michael', 'rivera collazos leonardo',
#        ...
#        'samis srl', 'flimsa repuestos y servicios s.a.c.',
#        'ortega rojas ruben dario', 'roman huaman leodan',
#        'feder & asociados s.a.c.', 'paucar ayca angelica',
#        'quispe carhuaz florissa', 'pastor calderon luz esther',
#        'corporacion emsac contratistas & servicios generales s.a.c.',
#        'baños portatiles channel s.a.c'],
#       dtype='object', name='razon_social', length=5149)

# %%
dict_razonsocial = {razon_social: i+1 if i < 20 else 0 for i, razon_social in enumerate(razon_social_list)}
dict_razonsocial
# Out:
# {'filmarg s.a.c.': 1,
#  'antachoque espinoza ernesto alonso': 2,
#  "repuestos ccori motor's e.i.r.l.": 3,
#  'lubrimaq e.i.r.l.': 4,
#  'brama transp y comerc. eirl.': 5,
#  'transportes angel ibarcena s.a.c.': 6,
#  'inversiones el amortiguador e.i.r.l.': 7,
#  'filtros san jorge sac': 8,
#  'benites marquina, leyter michael': 9,
#  'rivera collazos leonardo': 10,
#  'valdiviezo import e.i.r.l.': 11,
#  'home filter eirl': 12,
#  'ore quispe aristedes': 13,
#  'ln lima import s.a.c.': 14,
#  'repuestos urbina e.i.r.l.': 15,
#  'movilcar srl': 16,
#  'sanchez gonzales carmen rosa': 17,
#  'jofran peru s.a.c.': 18,
#  'ccori motor´s soluciones automotrices e.i.r.l.': 19,
#  'mamani mendoza, jorge rene': 20,
#  'corporacion jofran-clauste e.i.r.l.': 0,
#  'repuestos y lubricantes el trebol ica e.i.r.l.': 0,
#  'importaciones y representaciones garcia s.a.c.': 0,
#  'becerra donaires ida': 0,
#  'n c autopartes sac': 0,
#  'apaza tipula isaac': 0,
#  'huachua barrientos jorge alberto': 0,
#  'super grifo el tambo eirl': 0,
#  'inversur company s c r l': 0,
#  'valencia gamarra jose antenor': 0,
#  'becerra nina de palomino ana maria': 0,
#  'mendoza industrial sac': 0,
#  'vijoscham y cia s a c': 0,
#  'julca guillermo lolin rolando': 0,
#  'güere quintero joel david': 0,
#  'automotriz royal eirl': 0,
#  'inversiones kevin car & asociados s.a.c.': 0,
#  'oleocentro victor hugo hnos sac': 0,
#  'cayllahua hurtado edwin': 0,
#  'valdez auccapuma victor': 0,
#  'laura luque fernando raul': 0,
#  'automotores san miguel importaciones sac': 0,
#  'segovia service lubricantes s.a.c.': 0,
#  'importaciones m & j autopartes s.a.c.': 0,
#  'flores flores jesus rafael': 0,
#  'norka distribuciones e.i.r.l.': 0,
#  'lubricentros lider eirl': 0,
#  'lubricantes el rey eirl': 0,
#  'chumbimuni taza yenny gabriela': 0,
#  'autocentro repuestos multimarcas e.i.r.l.': 0,
#  'tecnologia constructora hermanos salazar s.a.c.': 0,
#  's & g pisfil s.a.c.': 0,
#  'herrera fernandez angie katherine': 0,
#  'sanchez de baca otilia margarita': 0,
#  'repuestos automotriz lalo e.i.r.l.': 0,
#  'compañia negociadora del sur s c r l': 0,
#  'repuestos toyonisa e.i.r.l.': 0,
#  'custodio sanchez yenifer': 0,
#  'peña aguirre jorge luis': 0,
#  'grupo hinostroza hnos s.a.c.': 0,
#  'lubricentro frenos y embragues ramos e.i.r.l.': 0,
#  'repuestos automotriz isaac e.i.r.l.': 0,
#  'gutierrez colmenares jeferson cristhian': 0,
#  'lubricentro gallarday s.a.c.': 0,
#  'representaciones e inversiones parj sa': 0,
#  'distribuidora e importadora peru motor eirl': 0,
#  'repuestos auto peru cars e.i.r.l.': 0,
#  'servicio automotriz solis s.a.c.': 0,
#  'oleocentro mobil car e.i.r.l.': 0,
#  'importaciones marquinho s.a.c': 0,
#  'repuestera trujillo srl': 0,
#  'servicios el llapita s.a.c.': 0,
#  'filtros y servicios margarita s.a.c.': 0,
#  'caceres pacuri yuver donny': 0,
#  'importaciones y distribuciones regalado e.i.r.l.': 0,
#  'rodriguez sanchez sergio francisco': 0,
#  'becerra donaires saul saturnino': 0,
#  'inversiones san francisco frenos y embragues sociedad anónima cerrada': 0,
#  'comercializacion y servicios lub mañuco eirl': 0,
#  'cambar y tapia automotriz  s.a.c': 0,
#  'r&d import collama e.i.r.l.': 0,
#  'global perla s car s.a.c.': 0,
#  'peña chiguala marita guisela': 0,
#  'repuestos nueva era eirl': 0,
#  'corporacion repuestos rafael rf sociedad anonima cerrada': 0,
#  'importadora de repuestos obaj s.a.c.': 0,
#  'filtros & multiservicios s.a.c.': 0,
#  'repuestos automotrices merino hnos s.a.c.': 0,
#  'diaz patatingo waldir': 0,
#  'lubricentro esergami miraflores  scrl': 0,
#  'distribuidora reluce s.a.c.': 0,
#  'cedimmotors s.r.l.': 0,
#  'autopartes romero s.a.c.': 0,
#  'importaciones karina hnos e.i.r.l.': 0,
#  'servicios corporativos muruhuay s.r.l': 0,
#  'muñoz vicente nestor': 0,
#  'becerra nina raquel': 0,
#  'grupo velasquez y asociados s.a.c.': 0,
#  'disvar sac': 0,
#  'aquino aylas marisol edita': 0,
#  'corporacion rod s.a.c.': 0,
#  'leman s distribuciones s.r.l.': 0,
#  'comercial cleofe eirl': 0,
#  'camavilca callupe bertha': 0,
#  'corporacion psel parts empresa individual de responsabilidad limitada': 0,
#  'quevedo julca david': 0,
#  'dkars repuestos s.a..': 0,
#  'repuestos vidal s.a.c.': 0,
#  'gq import del peru e.i.r.l.': 0,
#  'repuestos automotriz elizabeth e.i.r.l.': 0,
#  'repuestos armandito s.a.c.': 0,
#  'alese s.a.c.': 0,
#  'm&j maranatha s.a.c.': 0,
#  'grupo crj services s.a.c.': 0,
#  'rocha gutierrez alberto omar': 0,
#  'chumbimuni taza erika patricia': 0,
#  'zavaleta quijandria jhonny': 0,
#  'ramle s.a.c.': 0,
#  'frenos & embragues el gordo e.i.r.l.': 0,
#  'repuestos ore s.a.c.': 0,
#  'repuestos y lubricantes laval sac': 0,
#  'murillo oviedo shandro vladimir': 0,
#  'becerra s.a.c': 0,
#  'garcilazo relicario marcos david': 0,
#  'valenzuela atencio hector': 0,
#  'corporacion automotriz hikari s.a.c.': 0,
#  'gp filtros y mantenimiento s.a.c.': 0,
#  'corporacion santa rosita e.i.r.l.': 0,
#  'repuesto jhon s.r.l.': 0,
#  'lubricentros lider j & a e.i.r.l.': 0,
#  'r & r repuestos rafa e.i.r.l': 0,
#  'cavassa guzman bruno francisco': 0,
#  'repuestos & accesorios automotriz luren s.a.c.': 0,
#  'j & o repuestos flores s.r.l.': 0,
#  'castillo villegas santiago martin': 0,
#  'andrada serna daniel': 0,
#  'corporacion t.e.k import s.a.c.': 0,
#  'gotea ircañaupa yovana': 0,
#  'representaciones lubricar eirl': 0,
#  'kilometro cero group e.i.r.l.': 0,
#  'mb renting sa': 0,
#  'repuestos y lubricantes celis e.i.r.l.': 0,
#  'corporacion de empresas automotrices s.a.c.': 0,
#  'inversiones cetlam s.a.c.': 0,
#  'f & e rondinel e.i.r.l.': 0,
#  'repuestos balarezo s.a.c': 0,
#  'soligen s a c': 0,
#  'importaciones e inversiones generales dacl s.a.c.': 0,
#  'la puerta vasquez ricardo tomas': 0,
#  'laney srl': 0,
#  'repuestos miguelitos sac': 0,
#  'importaciones laura automotriz e.i.r.l.': 0,
#  'importaciones del sur e.i.r.l.': 0,
#  'segovia lube & gear s.a.c.': 0,
#  'lubrimotors aqp s.r.l.': 0,
#  'repuestera y mas s a c': 0,
#  'repuestera oem s.a.c.': 0,
#  'toledo rondan margarita elena': 0,
#  'implementos peru s.a.c.': 0,
#  'violeta espinoza de rosas e.i.r.l.': 0,
#  'acuña import e.i.r.l.': 0,
#  'vasquez diaz antonio caleb': 0,
#  'autopartes importacion s.a.c.': 0,
#  'gago arteaga raul rolando': 0,
#  'multiservicios calderon v e.i.r.l.': 0,
#  'lubricantes virgen del carmen l & d srl': 0,
#  'tincor e.i.r.l.': 0,
#  'c becerra s.a.c.': 0,
#  'sulla caceres david samuel': 0,
#  'automotriz nippon car e.i.r.l.': 0,
#  'i m beytia s a c': 0,
#  'importacion y distribucion de repuestos f & d e.i.r.l.': 0,
#  'filtros y repuestos andre e.i.r.l.': 0,
#  'importaciones geral motor s.a.c.': 0,
#  'soportes & suspensiones pinedo e.i.r.l.': 0,
#  'hospina pariona humbertina': 0,
#  'lubricantes pieyyra e.i.r.l.': 0,
#  'electronic katherine d & r srltda': 0,
#  'villcas quispe gisella vanessa': 0,
#  'rojas guio victor segundo': 0,
#  'team bolivar s.a.c.': 0,
#  'importadora de repuestos pareja s.a.c.': 0,
#  'lubricantes alania sac': 0,
#  'corporacion autosboutique 33.5 s.r.l.': 0,
#  'a & b inversiones jairo s.r.l.': 0,
#  'representaciones generales daffo e.i.r.l.': 0,
#  'amortiguadores massimo e.i.r.l.': 0,
#  'representaciones & veliz sac': 0,
#  'l & r becerra s.a.c.': 0,
#  'cordova rivera oswaldo': 0,
#  'bances gadea virginia del carmen': 0,
#  'repuestos marco antonio e.i.r.l.': 0,
#  'muñoz cuela luis antonio': 0,
#  'flores campos lidia': 0,
#  'jhosmin e.i.r.l.': 0,
#  'lubricantes rodriguez den s.a.c.': 0,
#  'repuestos y lubricantes virgencita de chapi s.r.l.': 0,
#  'automotriz salvatierra e.i.r.l.': 0,
#  'importaciones ore s.a.c.': 0,
#  'eliber repuestos y accesorios 2324 e.i.r.l.': 0,
#  'huillcas guzman jesica': 0,
#  'enriquez guevara norly': 0,
#  'quispe fernandez jhonny joel': 0,
#  'autopartes y lubricantes chipana e.i.r.l.': 0,
#  'valenzuela cabanillas renan': 0,
#  'lubricantes y servicios jorge e.i.r.l': 0,
#  'ferreteria y repuestos hidraulicos marlon s.a.c.': 0,
#  'importadora de repuestos r & a s.a.c.': 0,
#  'bambino motors s.r.l.': 0,
#  'filtros cajamarca e.i.r.l.': 0,
#  'inversiones gutyzel s.a.c.': 0,
#  'importacion automotriz peru atlanta s.a.c.': 0,
#  'peru cuormi e.i.r.l': 0,
#  'ancajima nuñez miguel ronal': 0,
#  'vicmar automotriz srl': 0,
#  'autofondo s.a.c.': 0,
#  'murillo palomino vladimiro': 0,
#  'inversiones j.j alvarez e.i.r.l.': 0,
#  'lubricentro lorendier e.i.r.l.': 0,
#  'repuestos diza e.i.r.l.': 0,
#  'huaman jara daniel': 0,
#  'valdez paucar miriam': 0,
#  'inversiones & representaciones robles e.i.r.l': 0,
#  'calderon garcia jenny rocio': 0,
#  'requejo hernandez saul': 0,
#  'diesel silver eirl': 0,
#  'oleocentro jae e.i.r.l.': 0,
#  'importaciones r. becerra. e.i.r.l.': 0,
#  'lubricantes y servicios junior s.a.c.': 0,
#  'paredes mosquera jesus antonio': 0,
#  'soluciones de yndustria, mineria,venta de repuesto s.a.c. - soldymver s.a.c.': 0,
#  'hisumotor s.a.c.': 0,
#  'jebes ecerf e.i.r.l.': 0,
#  'importaciones principe s.a.c.': 0,
#  'repuestos regalado e.i.r.l.': 0,
#  'repuestos jesica s.a.c.': 0,
#  's & s chacon s.a.c.': 0,
#  'inversiones san francisco srl': 0,
#  'soluciones automotrices m & g s.a.c.': 0,
#  'gonzales nieto jorge': 0,
#  'importaciones de repuestos osk e.i.r.l.': 0,
#  'multirepuestos sac': 0,
#  'la tienda del amortiguador e.i.r.l': 0,
#  'torres perez maribel doris': 0,
#  'lubricantes j c srl': 0,
#  'importaciones y servicios mazued eirl': 0,
#  'repuestos imports sakura motorss e.i.r.l.': 0,
#  'autopartes bueno s.a.c.': 0,
#  'oleocentro sandy srl': 0,
#  'jacho chambi juana francisca': 0,
#  'celso martinez soledad': 0,
#  'inversiones sostenibles v & m e.i.r.l.': 0,
#  'corporacion jofran f&s s.a.c.': 0,
#  'perez blasido nancy leonor': 0,
#  'huisa avendaño maria antonieta': 0,
#  'repuestos y lubricantes santa monica s.a.c.': 0,
#  'm & s mediterranea s.a.c.': 0,
#  'el centro de los repuestos paolo e.i.r.l.': 0,
#  'm&r cristobal s a c': 0,
#  'gomez flores de de la cruz vicentina': 0,
#  'muñoz huaman licida': 0,
#  'mecanica automotriz motor servis magno e i r l': 0,
#  'luna garcia ferfin miller': 0,
#  'porras ramos isidoro marino': 0,
#  'r. castro e.i.r.l.': 0,
#  'barrientos mendez justiniano': 0,
#  'repuestos montaño s.a.c.': 0,
#  'inversiones necht e.i.r.l.': 0,
#  'mateo parts s c r l': 0,
#  'inversiones arias lunahuana e.i.r.l.': 0,
#  'hanco sota jose nicolas': 0,
#  'macor automotriz e.i.r.l.': 0,
#  'palacios balvin helbert': 0,
#  'automotriz ebert s c r l': 0,
#  'diaz barrenechea cristian teodoro': 0,
#  'quispe anaya manuel': 0,
#  'purihuaman de la cruz, carlos': 0,
#  'repuestos anderson s.a.c.': 0,
#  'casas sovero daniela yamilet': 0,
#  'cardenas cuba gladys edith': 0,
#  'malaga mamani janet': 0,
#  'melendez y cia s.a.c.- melci s.a.c.': 0,
#  'navarro racing s.a.c.': 0,
#  'silva charcape carlos alberto': 0,
#  'representaciones automotriz c&j s.r.l.': 0,
#  'importadora comercializadora uldarico s.a.c.': 0,
#  'creaciones metalicas ortiz s.r.l.': 0,
#  'importacion distribucion y comercializacion mera group s.a.c.': 0,
#  'inversiones niño milagroso s.a.c.': 0,
#  'yanavilca yanavilca laval': 0,
#  'lubrinegocios crisben  s.a.c': 0,
#  'mamani patatinco marleny': 0,
#  'la suspension frenos y servicios e.i.r.l.': 0,
#  'l & s import peru s.a.c.': 0,
#  'repuestos y accesor. el paraiso e.i.r.l': 0,
#  'castillo de la cuba, jimmy': 0,
#  'perez saravia eloy erickson': 0,
#  'chavez condori anyelard eduardo': 0,
#  'altamirano layseca marly': 0,
#  'pino huamani teofilo': 0,
#  'dist.de lubric.y rep.aut.delusa srl': 0,
#  'servicios empresariales kugar s a c': 0,
#  'autorepuestos san isidro e.i.r.l.': 0,
#  'quispe rupaylla javier luis': 0,
#  'importaciones nueva era e.i.r.l.': 0,
#  'grupo alvi importadores s.a.c.': 0,
#  'lubristore motor service e.i.r.l.': 0,
#  'representaciones el fenix e.i.r.l': 0,
#  'inversiones mevery srl.': 0,
#  'servicentro la amistad e.i.r.l.': 0,
#  'world filter e.i.r.l.': 0,
#  'arevalo sanchez clara isabel': 0,
#  'torres madrid lidia mercedes': 0,
#  'wd servicios diesel e.i.r.l.': 0,
#  'multiservicios automotriz el mister gigante e.i.r.l.': 0,
#  'negociaciones abbycorp eirl': 0,
#  'quevedo julca elva': 0,
#  'lubricentro alvarez fast e.i.r.l.': 0,
#  'urbina vasquez higinio': 0,
#  'tito gutierrez mily': 0,
#  'cajacuri ñaupari jhonel arturo': 0,
#  'tecsel automotriz eirl.': 0,
#  'luque cala alberto': 0,
#  'repuestos y lubricantes carlitos e.i.r.l.': 0,
#  'bazan cerron sabi ana': 0,
#  'huaman barzola joel abe': 0,
#  'cruz herrera doris': 0,
#  'respuesto woong e.i.r.l.': 0,
#  'gonzales mamani maritza milagros': 0,
#  'mendoza quispe vilma norma': 0,
#  'lubriaccesorios virgen del carmen e.i.r.l.': 0,
#  'corporacion filtroil e.i.r.l.': 0,
#  's & s diperbat eirl': 0,
#  'inga orihuela elbio w.': 0,
#  'mangueras y conexiones peru s.a.c.': 0,
#  'finca green s.a.c.': 0,
#  'repuestos abanto eirl': 0,
#  'palieres stiven e.i.r.l.': 0,
#  'automotriz panchito e.i.r.l.': 0,
#  'coaquira feliciano oscar gil': 0,
#  'autoland accesorios y repuestos s.a.c.': 0,
#  'pfasa importaciones s.a.c.': 0,
#  'repuestos y representaciones frank eirl': 0,
#  'c.d.b. electric parts e.i.r.l.': 0,
#  'grandez navarro bedith': 0,
#  'centro de lubricantes y repuestos tamara e.i.r.l.': 0,
#  'avendano quino evangelina benita': 0,
#  'gamarra cruzado luis arquimedes': 0,
#  'repuestos jean murisa s.a.c': 0,
#  'oillub e.i.r.l.': 0,
#  'servicios generales candioti e.i.r.l.': 0,
#  'becerra nina carlos alberto': 0,
#  'autopartes charlie e.i.r.l.': 0,
#  'lubricentro carrera s.a.c.': 0,
#  'corporacion empresarial lucerito s.a.c.': 0,
#  'repuestos y accesorios chiclayo e.i.r.l.': 0,
#  'inversiones brake s.a.c.': 0,
#  'repuestos y lubricantes el rosario e.i.r.l': 0,
#  'rew representaciones s.a.c.': 0,
#  'car diesel trading s.a.c.': 0,
#  'repuestos sanchez vicente s.r.l.': 0,
#  'repuestos motor plaza s.a.c.': 0,
#  'repuestos laura automotriz e.i.r.l.': 0,
#  'garay gonzales elvis': 0,
#  'automotriz & repuestos el zorro e.i.r.l.': 0,
#  'lubricantes mega cars s.r.l.': 0,
#  'obando uceda grocio alamiro': 0,
#  'multiservicios iman e.i.r.l.': 0,
#  'corporacion autorep s.a.c.': 0,
#  'lubrillantas pajarito s.a.c.': 0,
#  'lubricantes y repuestos aypate srl': 0,
#  'comercial arb & bg e.i.r.l.': 0,
#  'importaciones luz s.a.c.': 0,
#  'quispe corimanya richard martin': 0,
#  'rupay bashualdo yersi abel': 0,
#  'hanco bonifacio roger': 0,
#  'inversiones automotrices zc s.a.c.': 0,
#  'lujan espiritu zady noemi': 0,
#  'jea lubricentro san isidro s.r.l.': 0,
#  'vilca automotriz e.i.r.l': 0,
#  'inversiones miol eirl': 0,
#  'lubricantes y servicios sudamerica e.i.r.l.': 0,
#  'luvisa representaciones eir ltda': 0,
#  'importaciones y representaciones santa maria sac': 0,
#  'inca tapia jessica norma': 0,
#  'servicentro mi pana s.r.l.': 0,
#  'autopartes rocha e.i.r.l.': 0,
#  'c. j. chavez srl': 0,
#  'quispe monge jhon': 0,
#  'senatino´s motor parts e.i.r.l.': 0,
#  'f & d import sac': 0,
#  'flores jimenez jose luis': 0,
#  'gutierrez espinoza alicia del pilar': 0,
#  'lubricantes acuario eirl': 0,
#  'autorama eirl': 0,
#  'rodamientos mogrovejo srl': 0,
#  'lubricantes enco srl': 0,
#  'industria y accesorios hidraulicas srl': 0,
#  'matta aparcana, miguel eduardo': 0,
#  'ramirez oscco rudy edison': 0,
#  'solsol tuesta carlos': 0,
#  'choque cruz matias': 0,
#  'lubrillante eirl': 0,
#  'automotive latin america s.a': 0,
#  'ortega padilla gleny dora': 0,
#  'mecatronica hco s.a.c.': 0,
#  'briceño esquivel sally emma': 0,
#  'r & r negociaciones rivera s.a.c.': 0,
#  'ld service company e.i.r.l.': 0,
#  'mamani quispe sonia': 0,
#  'alvarez cordova rosario mavel': 0,
#  'centon mamani david': 0,
#  'suero viza francisco': 0,
#  'mendoza huillca russel': 0,
#  'edquen altamirano ivan': 0,
#  'de la cruz tuesta, maria diomira': 0,
#  'comercial l & e e.i.r.l.': 0,
#  'constructores y motores e.i.r.l.': 0,
#  'lubricantes y servicios el resortes e i r l': 0,
#  'corporacion automotriz gamarra  e.i.r.l': 0,
#  'baldeon lopez alfredo urbano': 0,
#  'cantaro mejia arquimedes': 0,
#  'inversiones octopus s a c': 0,
#  'oleocentro santa rosa e.i.r.l.': 0,
#  'repuestos y accesorios san andres eirl': 0,
#  'importaciones y exportaciones estela s.a.c.': 0,
#  'condori inquilla wellfe': 0,
#  'rubio avila javier yonil': 0,
#  'cotelma e.i.r.l.': 0,
#  'huaman quispe delia': 0,
#  'fn lubricantes y repuestos s c r l': 0,
#  'distribuidora de lubricantes apolo s.r.l': 0,
#  'a & g autoparts s.a.c.': 0,
#  'w. autocam s.a.c.': 0,
#  'pernos & repuestos la solucion e.i.r.l.': 0,
#  'figueroa panduro, gina maria': 0,
#  'j y w repuestos s.a.c.': 0,
#  'repuestos santa maria s.r.l': 0,
#  'lujan rodriguez ymelda alejandrina': 0,
#  'auto spar s.a.c.': 0,
#  'dert inversiones peru s.a.c.': 0,
#  'lubrillantas bueno s a c': 0,
#  'basto orellano eliana maela': 0,
#  'distribuciones oil del sur e.i.r.l.': 0,
#  'inversiones & servicios giosara s.a.c': 0,
#  'valenzuela atencio carlos andres': 0,
#  'remave sac': 0,
#  'repuestos car buss srl': 0,
#  'velasquez pajuelo angel': 0,
#  'solucion automotriz arequipa e.i.r.l.': 0,
#  'sullca huanca raul fritz': 0,
#  'autoser peru e.i.r.l.': 0,
#  'asto cotrina pablo jose': 0,
#  'comercial de repuestos durcon s.r.l.': 0,
#  'laboratorio diesel senatinos s.a.(ladise)': 0,
#  'robles ambrosio jair alexis': 0,
#  'repuestos m mendoza eirl': 0,
#  'doja import s.a.c.': 0,
#  'aparco urrutia manuel': 0,
#  'hm inversiones lubricantes s.r.l.': 0,
#  'choque huallpa rodrigo': 0,
#  'multiservicios cemar s.a.c.': 0,
#  'rally s.a.c.': 0,
#  'giza & cia s.a.c.': 0,
#  'mendoza quispe walter fabian': 0,
#  'reminsur s.r.l.': 0,
#  'new car import s.a.c.': 0,
#  'repuestos y representaciones h.p.g. e.i.r.l.': 0,
#  'servicios automotrices falcar  s . r l': 0,
#  'automotriz general del peru s a': 0,
#  'requejo yacila ayuvi': 0,
#  'multillantas san ignacio s.a.c.': 0,
#  'service center & transport viccar s.a.c.': 0,
#  'autopartes percy car s.r.l.': 0,
#  'disffena srl': 0,
#  'lubricentro barrio magistral s.a.c.': 0,
#  'escobal julcamoro rosa elvira': 0,
#  'automotriz sanchez e.i.r.l': 0,
#  'cahuana espinoza, milano': 0,
#  'cardenas soria jhoselyn susan': 0,
#  'estacio tamara froilan': 0,
#  'automotores tingo maria s.r.l.': 0,
#  'cedemarc distribuciones y soluciones e.i.r.l': 0,
#  'castillo de la cuba jimmy': 0,
#  'taco gutierrez jack harry': 0,
#  'berrocal casimiro nadia yesenia': 0,
#  'octavios s.a.c.': 0,
#  'castro ccellccascca matilde': 0,
#  'repave sac': 0,
#  '3 h & p imsel diesel s.a.c.': 0,
#  'velasquez leon cesar alberto': 0,
#  'lujan alayo juliany pricila': 0,
#  'sarmiento nuñez ñebisa': 0,
#  'a & l comercial cotrado e.i.r.l.': 0,
#  'comercializadora dominga s.a.c': 0,
#  'quispe paquiyauri teodoro': 0,
#  'inversiones san francisco frenos y embragues s a c': 0,
#  'lubricentro virgen del rosario s.r.l.': 0,
#  'magda autos y servicios s.a.c.': 0,
#  'otiniano luis darwin paul': 0,
#  "lubricentro's cusco e.i.r.l": 0,
#  'multiservicios e ingenieria fuerza motriz s.r.l.': 0,
#  'inversiones & representaciones jara e.i.r.l.': 0,
#  'mamani mendoza luis alberto': 0,
#  'e & e servicios e importaciones e.i.r.l.': 0,
#  'central korea & alebash e.i.r.l.': 0,
#  'triny rental s.a.c.': 0,
#  'lizonde juarez victor': 0,
#  'janampa rivera rosalyn selmira': 0,
#  'repuestos y accesorios r & r sac': 0,
#  'comerc y serv rolando huertas srl': 0,
#  'inversiones nicole & smith s.a.c.': 0,
#  'rogger automotriz e.i.r.l.': 0,
#  'racing center s.a.c.': 0,
#  'collazos paz de rivera lucy virginia': 0,
#  'laurente ore clotilde': 0,
#  'zarate mamani maria soledad': 0,
#  'huancachoque llalla luis': 0,
#  'empresa de transporte rapido vip s.a.c': 0,
#  'julca guillermo jhon alvin': 0,
#  'romani motors e.i.r.l.': 0,
#  'automotriz & servicios adriano s.a.c.': 0,
#  'group murillo enterprise e.i.r.l.': 0,
#  'mallqui turpo carolina': 0,
#  'c m representaciones eirl': 0,
#  'inversiones matos s.a.c.': 0,
#  'vallejos sertek corporation s a c': 0,
#  'eguizabal correa sandra hilda': 0,
#  'lidman s.r.l.': 0,
#  'repuestos y servicios baldeon srl': 0,
#  'toledo rondan de nolasco judith rosa': 0,
#  'ruiz rodriguez lloni william': 0,
#  'repuestos freddy s a c': 0,
#  'melgarejo flores, teodora': 0,
#  'brake solution e.i.r.l.': 0,
#  'atencia aguilar teddy': 0,
#  'inga ponce julio cesar': 0,
#  'importaciones apostol santiago eirl': 0,
#  'lubricentro pipo s s.a.c.': 0,
#  'frenos & embragues crespo s.a.c.': 0,
#  'arias abarca martha': 0,
#  'huaman huaripuma julia marilu': 0,
#  'djm importador de rodamientos e.i.r.l.': 0,
#  'auto repuestos el duro s.a.c': 0,
#  'cabrera ventura carlos raul': 0,
#  'reimsur s.a.c.': 0,
#  'peña alva mariluz milagros': 0,
#  "corporacion mo & ca'r s.a.c.": 0,
#  'lubricentro alf e.i.r.l.': 0,
#  'automotriz yokoyama e.i.r.l.': 0,
#  'ojeda chu pedro rafael': 0,
#  'muñoz vicente reyna': 0,
#  'compañia la alborada san pedro e.i.r.l.': 0,
#  'servicentro jabsa sa': 0,
#  'repuestos ñaupari srl': 0,
#  'regalado valle eloy maximiliano': 0,
#  'valdivia cruz john abel': 0,
#  'quiroz cardenas waldir pablo': 0,
#  'obando garivay gladis isela': 0,
#  'chambi pari luis alfredo': 0,
#  'centro automotriz campos e.i.r.l.': 0,
#  'oil change retail s.a.c': 0,
#  'corporacion k & r car s.a.c': 0,
#  'portuguez sanchez otto pablo': 0,
#  'autopartes y lubricantes srl': 0,
#  'inversiones y servicios maranatha e.i.r.l.': 0,
#  'lubricentro medular 2 s.a.c.': 0,
#  'frenosm e.i.r.l.': 0,
#  'r & f representaciones duran import e.i.r.l': 0,
#  'david quispealaya castilla s.a.c.': 0,
#  'repuestos frank e.i.r.l.': 0,
#  'corporacion a & p s.a.c.': 0,
#  'ruiz saldaña fernando': 0,
#  'tejada servicios multiples s.a.c.': 0,
#  'marmolejo sanabria edwin leonardo': 0,
#  'repuestos y representaciones j & n vicente eirl': 0,
#  'r & l autoparts sac': 0,
#  'negociaciones viland e.i.r.l.': 0,
#  'repuestos automotriz cabrera de liz madeleyne cabrera crespo eirl': 0,
#  'requejo chang jaret eduardo': 0,
#  'fuentes bartra carlos enrique': 0,
#  'torres rivera jepsen pedro': 0,
#  'lubricentro choque eirl': 0,
#  'perez yucra magda yoana': 0,
#  'canchumanya inga rogelio': 0,
#  'repuestos santa ana srl': 0,
#  'carrion meza yrma': 0,
#  'valdivia inga giver': 0,
#  'lubricentro automotriz el pedregal eirl': 0,
#  'limache rosales giovanna': 0,
#  'b & l asociados s a': 0,
#  'repuestos zamora srl': 0,
#  'j.j. maslucan eirl': 0,
#  'neumaticos j.c. e.i.r.l.': 0,
#  'automotriz alvarado e.i.r.l.': 0,
#  'yanavilca esteban javier rene': 0,
#  'silva inversiones y representaciones e.i.r.l': 0,
#  'inversiones lexus card e.i.r.l.': 0,
#  'pinedo peña raul octavio': 0,
#  'lubricantes mathias s.a.c.': 0,
#  'automotriz lavagna sa': 0,
#  'jb&dv soluciones integrales e.i.r.l.': 0,
#  'motores pizarro s.a.c.': 0,
#  'inversiones montalvo e hijos e.i.r.l.': 0,
#  'hualla sanchez gustavo paul': 0,
#  'izaguirre romero juan': 0,
#  'camala huanca sandra': 0,
#  'barzola parian magdalena maria': 0,
#  'garcia ramirez johan emerson': 0,
#  'vican solano joackin': 0,
#  'full encendido e.i.r.l': 0,
#  'toyomotors srl': 0,
#  'automotriz f & d import s.a.c.': 0,
#  'multiservis venezuela e.i.r.l.': 0,
#  'huaman ubillus ana elisabet': 0,
#  'la casa del chofer s a': 0,
#  'guevara distrilub s.a.c.': 0,
#  'lubservice e.i.r.l.': 0,
#  'bernal garcia yrma maruja': 0,
#  'repuestos acuña torres s.a.c.': 0,
#  'automotriz ebf s a': 0,
#  'ortiz gamboa juan arturo': 0,
#  'cr y ch multiservicios s.a.c.': 0,
#  'master automotriz s.a.c.': 0,
#  'lubricentro virgen maria magdalena e.i.r.l.': 0,
#  'caleand s.a.c.': 0,
#  'avalos gutierrez cintya': 0,
#  'repuestos & servicios katheryn e.i.r.l.': 0,
#  'rodanorte & hnos clb s.r.l.': 0,
#  'mendieta torres de mendoza margarita': 0,
#  'distribuidora de lubricantes lad e.i.r.l': 0,
#  'elibem import e.i.r.l.': 0,
#  'j & c diesel corporation s.a.c.': 0,
#  'distribuidora g y v s.a.c.': 0,
#  'alvarez rodriguez denith': 0,
#  'distribuidora dsl sac': 0,
#  'camposano quispe jasmany': 0,
#  'aguirre garcia nestor alfonso': 0,
#  'ratto cortez yannina shirley': 0,
#  'araujo representaciones s.a.c.': 0,
#  'moya luque lilia bina': 0,
#  'jimenez simpe haydee mariluz': 0,
#  'cruz lopez maria consuelo': 0,
#  'lopez soto santos amalia': 0,
#  'autopremium e.i.r.l.': 0,
#  'representaciones christopher & danna e.i.r.l.': 0,
#  'solis figueroa maryory milagros': 0,
#  'fabrifilter maquinaria service e.i.r.l.': 0,
#  'inversiones agricar e.i.r.l.': 0,
#  'figueroa solis felix julio': 0,
#  'fabrifilter maquinarias s.a.c.': 0,
#  'estacion de servicios vicky car s sac': 0,
#  'fadirma sr ltda': 0,
#  'autopartes dayana e.i.r.l.': 0,
#  'representaciones yacar eirl': 0,
#  'isis motors e.i.r.l.': 0,
#  'flores baytan ana maribel': 0,
#  'distrib de rptos y serv dijofra srl': 0,
#  'valer bravo cintia aracely': 0,
#  "mega part' s tejeda s.r.l.": 0,
#  'm & a vilcar s.r.l.': 0,
#  'samar ortiz nathalie angie': 0,
#  'jp outsourcing group s.a.c.': 0,
#  'castañeda cisneros jose adriano': 0,
#  'industrias metal mecanica peña srl': 0,
#  'freno servicio surquillo eirl': 0,
#  'ecolavados e.i.r.l.': 0,
#  'laboratorio s & r diesel e.i.r.l.': 0,
#  'chipana mendoza nestor': 0,
#  'mendoza bautista emilio erasmo': 0,
#  'lubriservicios virgen de chapi s.r.l.': 0,
#  '2m micon s.a.c.': 0,
#  'ticona huahuasoncco ines irene': 0,
#  'repuestos genuinos eirl': 0,
#  'jf repuestos y lubricantes s.r.l': 0,
#  'quiliano angulo heraldo arturo': 0,
#  'reyna cosme maribel pilar': 0,
#  'inversiones los angeles e.i.r.l.': 0,
#  'importaciones g & r peru s.a.c.': 0,
#  'valenzuela cabanillas melanio': 0,
#  'automotriz diesel el gato sac': 0,
#  'transnational corporation pisfil s.a.c.': 0,
#  'embragues y frenos chasqui e.i.r.l.': 0,
#  'sauñe janampa carlos wilian': 0,
#  'multiservicios y repuestos antonio s.a.c.': 0,
#  'lopez chuquillanqui beatriz': 0,
#  'chamba pinto luis': 0,
#  'condor rapri juan jose': 0,
#  'taller 298 ica s.a.c.': 0,
#  'trini comercial srl': 0,
#  'meza perez janeth karina': 0,
#  'sanchez ayquipa, ana maria': 0,
#  'vilmar s.a.c': 0,
#  'caceres romero jorge avilio': 0,
#  'urday araucano juan salvador': 0,
#  'automotriz huamanga eirl': 0,
#  'flores vilcamiche diego angel': 0,
#  'larico lima de nuñez luz marina': 0,
#  'importadora mexico e.i.r.l.': 0,
#  'dpedro e.i.r.l.': 0,
#  'rios nuñez jair alexis pablo': 0,
#  'di-man -centroservis s.r.l.': 0,
#  'arl mega autos el chino e.i.r.l.': 0,
#  'campuzano pascual luis enrrique': 0,
#  'importadora de repuestos silva s.r.l.': 0,
#  'felipe ramos luis angel': 0,
#  'espino ayvar dianed': 0,
#  'cj sistemas automotrices eirl': 0,
#  'jopesa distribuidora de lubricantes srl': 0,
#  'inversiones rincer s.a.c.': 0,
#  'negso s.a.c.': 0,
#  'castillo mallma adriel': 0,
#  'los angeles asociados s.a.c': 0,
#  'rebasa import s.a.c.': 0,
#  'galindo conde sofia': 0,
#  'repuestos david diesel eirl': 0,
#  'vargas bejar dennis josue': 0,
#  'moi-sa automotriz srl': 0,
#  'inversiones e importaciones cossisel s.a.c.': 0,
#  'multiservicios djb-luis e.i.r.l': 0,
#  'orellana pocmucha ronny renzo': 0,
#  'tarazona arratea liz caterine': 0,
#  'sorsa retail s.c.r.l': 0,
#  'rosymar peru s.a.c.': 0,
#  'repuestos y lubricantes zavaleta ica sur e.i.r.l.': 0,
#  'autolam servicios generales e.i.r.l.': 0,
#  'rhojas negocios y servicios s.r.l.': 0,
#  'horna alcarraz jackson kirk': 0,
#  'ng - khar union s.r.l.': 0,
#  'freno servicio alfa s.r.ltda.': 0,
#  'gebry repuestos automotrices e.i.r.l': 0,
#  'importadora y comercializadora cz s.r.l.': 0,
#  'corporation import matrix sac': 0,
#  'celestino flores humberto ricardo': 0,
#  'laura quispe dante zosimo': 0,
#  'huaman quispe jhonny oscar': 0,
#  'velasquez andia liliana mariel': 0,
#  'alcantara macuri newton vladimir': 0,
#  'tito molina irineo': 0,
#  'galvez campos niger yuan': 0,
#  'servicios generales clucht part representation s.a.c.': 0,
#  'repuestos leon del sur eirl': 0,
#  'sanchez romero david': 0,
#  'cotrina guevara wilson urias': 0,
#  'jd importadora-distribuidora s.r.l.': 0,
#  'rosas gonzales felix timoteo': 0,
#  'a f boullosa scr ltda': 0,
#  'inversiones liana e.i.r.l.': 0,
#  'robles trabraj mijail raul': 0,
#  'pintado gonza maria melania': 0,
#  'espiritu usuriano yolita': 0,
#  'espinoza carhuancho miriam amelia': 0,
#  'aliaga ramon cecilio alberto': 0,
#  'mayta morales humberto alfredo': 0,
#  'inga leon edgar german': 0,
#  'amlumi e.i.r.l.': 0,
#  'romero diesel sac': 0,
#  'ruiz quispe juan carlos': 0,
#  'representaciones edusa e.i.r.l.': 0,
#  'pecho diesel parts e.i.r.l.': 0,
#  'baldeon general services s.a.c.': 0,
#  'distribuidora e importadora el sol s.a.c.': 0,
#  'autotronica sercar e.i.r.l': 0,
#  'distribuidora los angeles e.i.r.l.': 0,
#  'davalos import s.a.': 0,
#  'cerdan soberon walter': 0,
#  'gutierrez mantari william arquimedes': 0,
#  'importaciones becerra s.a.c.': 0,
#  'yacila marchan audry janet': 0,
#  'isla de la cruz julio enrique': 0,
#  'elibem truck e.i.r.l.': 0,
#  'alcapiab e.i.r.l.': 0,
#  'toribio obregon edwin neftali': 0,
#  'siguenza negociaciones servicios generales s.c.r.l': 0,
#  'inversiones & repuestos fernandito s.a.c.': 0,
#  'garcia torres abraham david': 0,
#  'l h b importaciones s a c': 0,
#  'autoniza s.a.c.': 0,
#  'herrera espinoza richard david': 0,
#  'ticllasuca zañudo leonardo antonio': 0,
#  'valdez delao alfredo panfilo': 0,
#  'repuestos y accesorios nikocar e.i.r.l': 0,
#  'autoservicios señor de luren s.r.l.': 0,
#  'salim part s.r.l.': 0,
#  'repuestos y autopartes el colorao s.a.c': 0,
#  'j & a multiservicios chavez s.a.c.': 0,
#  'raquel becerra e.i.r.l.': 0,
#  'peru car service sac': 0,
#  'multiservicios y llantas beda eirl': 0,
#  'campos janampa de mejia yane merly': 0,
#  'las palmas contratistas generales s.r.l.': 0,
#  'taype curihuamani jose manuel': 0,
#  'repuestos brayan e.i.r.l.': 0,
#  'importaciones gold sherman e.i.r.l.': 0,
#  'bustamante marrufo marcos antonio': 0,
#  'mendoza arrieta, marcelo': 0,
#  'torres flores aurea': 0,
#  'repuestos rene diesel eirl': 0,
#  'repuestos multicar e i r l': 0,
#  'repuestos elibem importaciones s.r.l.': 0,
#  'grupo resedisa s.a.c.': 0,
#  'multi-repuestos diesel s.r.l.': 0,
#  'negociaciones & lubricantes el dorado s.a.c.': 0,
#  'martinez revilla valerio': 0,
#  'quintero ortega de guere julia': 0,
#  'eurocar.m e.i.r.l': 0,
#  'castañeda chavez daynel zeigler': 0,
#  'repuestos montenegro s c r ltda': 0,
#  'r & a camiones y servicios s.r.l.': 0,
#  'cabrejos diaz jeremy eli': 0,
#  'universo import peru s.a.c.': 0,
#  'cerdan vargas santos manuel': 0,
#  'callañaupa ramos saul': 0,
#  'ramirez tito, amparo': 0,
#  'lipa barrios carla yoselyn': 0,
#  'direpsa s.a.c': 0,
#  'zavala chachi artemio': 0,
#  'simeon hospina dulio': 0,
#  'quispe flores miuler bernabe': 0,
#  'afimotors s.c.r.l.': 0,
#  'repuestos & lubricantes mega cars e.i.r.l.': 0,
#  'repuestos zavala s.a.c.': 0,
#  'distribuidora electrobosh eirl': 0,
#  'condori qquesuallpa petrona': 0,
#  'inversiones hacasa s.a.c.': 0,
#  'tanta bazan ilsio joel': 0,
#  'repuestos & servicios barzola empresa individual de resp. ltda': 0,
#  'multiservicios vega & ubaldo e.i.r.l.': 0,
#  'romero arauco luis junior': 0,
#  'narciso de la cruz dante solano': 0,
#  'importadora y distribuidora jimenez eirl': 0,
#  'chalco dongo jesus salvador': 0,
#  'figueroa alvinagorta juan carlos': 0,
#  'dionicio lopez humberto antonio': 0,
#  'mv bearing e.i.r.l.': 0,
#  'el inge inversiones jr s.a.c.': 0,
#  'gutierrez yvana jose eduardo': 0,
#  'diaz lopez florentino': 0,
#  'anchiraico noreña luis orlando': 0,
#  'lubricantes continental eirl': 0,
#  'repuestos y accesorios m.a.p e.i.r.l.': 0,
#  'grupo sensei peru s.a.c': 0,
#  'alcantara macuri jeancarlos gipson': 0,
#  'autorepuestos & ferreteria santo tomas sac': 0,
#  'melendrez huanccollucho diana carolina': 0,
#  'mamani huanca sonia amelia': 0,
#  'chalco ojeda victoria': 0,
#  'trujillo espinoza teodomira': 0,
#  'imelcons e.i.r.l.': 0,
#  'mantari gutierrez wilfredo antony': 0,
#  'grupo toyosan sac': 0,
#  'soto pilco edgar moises': 0,
#  'helix renting s.a.c.': 0,
#  'repuestos kelvingonzales s.a.c.': 0,
#  'porras valencia isaac eberth': 0,
#  'lucarbal rent a car e.i.r.l.': 0,
#  'representaciones henry diesel e.i.r.l.': 0,
#  'corporacion viljor e.i.r.l.': 0,
#  'ronceros felix veruzka lelia': 0,
#  'olivera imata victor': 0,
#  'frenos servicios huancayo sac': 0,
#  'roque quispe jose armando': 0,
#  'lubrillantas piura s.r.l.': 0,
#  'muelles calero del peru s.a': 0,
#  'shin import s.a.c.': 0,
#  'import car audio e.i.r.l.': 0,
#  'allauca perez yolanda': 0,
#  'rem diesel e.i.r.l.': 0,
#  'servicentro union distribuciones e.i.r.l.': 0,
#  'perez saavedra jino': 0,
#  'lubrimotors m&v sanchez e.i.r.l.': 0,
#  'total motors s.a.c.': 0,
#  'loredo de aliaga monica': 0,
#  'servimac sac': 0,
#  'inga arangurí martín daniel': 0,
#  'huacho pacco sofia': 0,
#  'yacila martinez henry': 0,
#  'lubricentro vitocho e.i.r.l.': 0,
#  'inversiones centauro sac': 0,
#  'valencia mamani jose antonio': 0,
#  'maina merma ladislao': 0,
#  'distribuidora de autopartes zavala s.a.c.': 0,
#  'tarqui choque fidel': 0,
#  'corporacion dasha s.a.c.': 0,
#  'lubricantes luisa s.a.c.': 0,
#  'ruiz saldaña, fernando': 0,
#  'noreña tolentino, blacido segundino': 0,
#  'olivera zea, bernabe': 0,
#  'muñoz saavedra fabian': 0,
#  'las magnolias s c r l': 0,
#  'motormaq s.a.c.': 0,
#  'narvaez zuñiga cesilia paola': 0,
#  'curo lima angel': 0,
#  'jdh comercial e.i.r.l.': 0,
#  'camarena de la cruz, hugo raul': 0,
#  'santiago santiago diana carolina': 0,
#  'multiservicios chira s.r.l.': 0,
#  'bautista ortiz de abrigo yannet doris': 0,
#  'automotriz renzo h.v. s.a.c': 0,
#  'gutierrez condori flora maria': 0,
#  'ticona candia edwin': 0,
#  'toralva vasquez fernando mario': 0,
#  'nacho electromotriz e.i.r.l.': 0,
#  'autobacks e.i.r.l.': 0,
#  'representaciones e inversiones lugo s.a.c.': 0,
#  'carranza alvis iris jovany': 0,
#  'sucesion indivisa chancafe guanilo nicolas': 0,
#  'global petrol e.i.r.l.': 0,
#  'jsh repuestos e.i.r.l.': 0,
#  'sullca huaquisto madeleyne b': 0,
#  'inversiones mdo s.a.c.': 0,
#  'lubricantes jose antonio e.i.r.l.': 0,
#  'paredes velezmoro william norberto': 0,
#  'inchcape latam perú s.a.': 0,
#  'carcamo spagnol carlos enrique': 0,
#  'macassi quispe jesus humberto': 0,
#  'jdvs e.i.r.l': 0,
#  'america diesel s.a.c.': 0,
#  'empresa servicios multiples grupo ramos empresa individual de': 0,
#  'sanchez lozano milagros': 0,
#  'medina garcia yhordi chali': 0,
#  'nuñez claros renzo ivan': 0,
#  'wilar service s.a.c.': 0,
#  'yana suaña diana irene': 0,
#  'calisaya bonifas lourdes': 0,
#  'industrias y servicios a.r. e.i.r.l.': 0,
#  'repuestos y servicios dersykori s.r.l.': 0,
#  'corporacion importadora san roman s.r.l.': 0,
#  'inversiones rodamientos canales s.a.c.': 0,
#  'hayro s service diesel s.a.c.': 0,
#  'zarate sotelo delta julieta': 0,
#  'multiservicios javier import e.i.r.l': 0,
#  'servicentro morales y servicios j & k e.i.r.l': 0,
#  'filtros rodesani s.a.c.': 0,
#  'grupo jose miguel s.r.l': 0,
#  'distribuidora de lubricantes mendoza s.a.c.': 0,
#  'flores fernandez herminio': 0,
#  'grupo pacifico lubricantes e.i.r.l.': 0,
#  'becerra nina maria luz': 0,
#  'corporativo piloto s.a.c.': 0,
#  'hanco sota cecilio lucas daniel': 0,
#  'lubriser hugo e.i.r.l.': 0,
#  'vidal zavaleta piero jhonson': 0,
#  'marcapura cruz zoila luz': 0,
#  'frenos y embragues soca s.a.c': 0,
#  'autobacks miraflores s.a.c': 0,
#  'muelle centro cusco & autopartes e.i.r.l.': 0,
#  'bueno rabanal de flores maritza': 0,
#  'mejia racing oil e.i.r.l.': 0,
#  'cayo pari marina': 0,
#  'inversiones y negocios central s.a.c.': 0,
#  'repuestos y lubricantes lucho e.i.r.l': 0,
#  'chavez janampa alipio': 0,
#  'caceres portocarrero rory franklin': 0,
#  'industria panther s srl': 0,
#  'repuestos alfaro eirl': 0,
#  'inversiones & negociaciones j.b. s.a.c.': 0,
#  'silva llontop julio cesar': 0,
#  'lopez rosales yolanda juana': 0,
#  'corporacion dunamis j & r s.a.c.': 0,
#  'inversiones topab e.i.r.l': 0,
#  'autobacks distribuciones e.i.r.l.': 0,
#  'del aguila yupanqui quirliang': 0,
#  'ancajima nuñez yanina margot': 0,
#  'ruiz grandez karen katherine': 0,
#  'corporacion mekatek s.a.c.': 0,
#  'visam diesel s.a.c.': 0,
#  'mamani gomez jorge luis': 0,
#  'meza tadeo rodin': 0,
#  'a. rojas contratistas generales s.a.c.': 0,
#  'corporacion pernocenter scrl': 0,
#  'choque cruz agustin': 0,
#  'quecaño quispe alex': 0,
#  'pfuro e.i.r.l.': 0,
#  'lubricantes y repuestos centenario e.i.r.l': 0,
#  'repart import s a c': 0,
#  'esmyco la nacional srl': 0,
#  'frenos mexico s.a.c.': 0,
#  'suca portugal ronny vladimir': 0,
#  'frenos y muelles nueva era e.i.r.l.': 0,
#  'de auto japones import & export e.i.r.l.': 0,
#  'central del carro empresa individual de responsabilidad limitada': 0,
#  'hermanos llanos s.a.c.': 0,
#  'lubriwash oil service s.a.c. luserv s.a.c.': 0,
#  'inga eguiluz sebastian alejandro': 0,
#  't y m grupo molina e.i.r.l.': 0,
#  'lubricentro balboa sac': 0,
#  'vilcarano chavez zenon': 0,
#  'chavez mamani ruth': 0,
#  'gamboa valverde christian edinson': 0,
#  'san martin autopartes e.i.r.l.': 0,
#  'rodriguez moreno susana rosa': 0,
#  'caceres cayo edgar jesus': 0,
#  'inversiones karol d & d empresa individual de responsabilidad limitada': 0,
#  'palomino quispe cristian waldir': 0,
#  'canahualpa reynoso lucio': 0,
#  'garcia ramirez francisco camilo': 0,
#  'huaman huillca jose alejandro': 0,
#  'andia llamacponcca erick erwins': 0,
#  'vidal donayre carlos armando': 0,
#  ...}

# %%
data['cod_razon_social'] = data.razon_social.map(dict_razonsocial)
data
# Out:
#             fecha                              razon_social  \
# 0      2021-01-04              casas sovero daniela yamilet
# 1      2021-01-04              casas sovero daniela yamilet
# 2      2021-01-04                 gc service & parts s.a.c.
# 3      2021-01-05               lopez rosales yolanda juana
# 4      2021-01-06                     palante flotas s.a.c.
# ...           ...                                       ...
# 576016 2024-05-17  empresa de transportes sol de oro s.a.c.
# 576017 2024-05-22     lubricentro virgen del rosario s.r.l.
# 576018 2024-05-22     lubricentro virgen del rosario s.r.l.
# 576019 2024-05-23                     gqr autopartes s.a.c.
# 576020 2024-05-23                     gqr autopartes s.a.c.
#
#                                nombre_articulo       fuente_suministro  \
# 0                             focos h1 12v 55w                   narva
# 1                focos h4 12v 100x90 rallye(7)                   narva
# 2           filtro de aire 1° af25729 055134r1           mann - brasil
# 3       pastillas de freno ceramica d1567 delt      wagner - pastillas
# 4                    aceite sae20w50 sn racing               valvoline
# ...                                        ...                     ...
# 576016               llantas himito nl118 18pr                 deruibo
# 576017        trapecio del lh inf  48069-0k090  ito koyama - trapecios
# 576018        trapecio del rh inf  48068-0k090  ito koyama - trapecios
# 576019         palier 25x23x55 c/anillo ni-214   ito koyama - palieres
# 576020                 copa de palier 23x31x34   ito koyama - palieres
#
#         cantidad  venta_usd  venta_pen        costo  \
# 0           50.0      51.27     185.80   134.870000
# 1          300.0     597.46    2165.20  1413.050100
# 2            8.0     152.54     552.80   310.150000
# 3            2.0      42.36     153.68    96.560000
# 4           90.0     861.86    3129.41  2323.670040
# ...          ...        ...        ...          ...
# 576016      20.0    2796.61   10425.76  7899.060000
# 576017       1.0      59.92     223.68   119.090000
# 576018       1.0      59.92     223.68   118.290000
# 576019       6.0      63.94     239.33   159.430002
# 576020      16.0     202.79     759.04   529.950000
#
#                              cobrador      mes  departamento_num  \
# 0                 vega zúñiga enrique  2021-01               1.0
# 1                 vega zúñiga enrique  2021-01               1.0
# 2                             oficina  2021-01               1.0
# 3              cañas flores alan joel  2021-01               4.0
# 4             olórtegui manrique juan  2021-01               1.0
# ...                               ...      ...               ...
# 576016  fernández monge juan fernando  2024-05               1.0
# 576017   valderrama acuña luisa maria  2024-05               2.0
# 576018   valderrama acuña luisa maria  2024-05               2.0
# 576019            vega zúñiga enrique  2024-05               1.0
# 576020            vega zúñiga enrique  2024-05               1.0
#
#         cod_vendedor  cod_razon_social
# 0                 13                 0
# 1                 13                 0
# 2                 28                 0
# 3                 21                 0
# 4                 30                 0
# ...              ...               ...
# 576016            22                 0
# 576017             0                 0
# 576018             0                 0
# 576019            24                 0
# 576020            24                 0
#
# [576021 rows x 13 columns]

# %%
cobrador_list = list(data.cobrador.value_counts().index)
cobrador_list
# Out:
# ['olórtegui manrique juan',
#  'fernández monge juan fernando',
#  'vega zúñiga enrique',
#  'oficina provincia',
#  'oficina lima',
#  'saavedra cicirello jose doming',
#  'revolledo humala paulo',
#  'vega ampuero luis carlos',
#  'osorio echevarria roger alcides',
#  'rojas vasquez abner',
#  'escobar salinas miguel',
#  'valle atahuaman toribio',
#  'caceres julca david',
#  'gil zuñiga climaco',
#  'castro elias harol armando',
#  'bravo crisanto david esteban',
#  'alarcon altamirano pepe',
#  'alarcon altamirano mayco',
#  'pepe alarcón',
#  'ponce galindo lady skarlet',
#  'valderrama acuña luisa maria',
#  'quispe tasa william',
#  'torres quiñones luis alberto',
#  'todos',
#  'oficina',
#  'cañas flores alan joel',
#  'cañas flores alan',
#  'rojas vasquez keneth',
#  'huaman jara daniel',
#  'omar velarde durand',
#  'fernandez perez genesis victoria',
#  'vidaurre namuch raul alfredo',
#  'vega ampuero luis',
#  'scarlett ponce galindo',
#  'ponce galindo lady rubi',
#  'ruiz revolledo jose luisxx',
#  'osis alarcon maximo',
#  'ponce rubi',
#  'brsvo crisanto david esteban',
#  'caja oficina lima',
#  'ruiz revolledo jose luis',
#  'revatta escobar rogelio',
#  'vega ganoza jose carlos',
#  'cañas alan',
#  'lupaca castañeda gisela yanet',
#  'apli, notas de abono at',
#  'deposito banco',
#  'ningún vendedor',
#  'apli. notas abono, at y regalo',
#  'aplicacion notas de abono y at',
#  'valdivia hildalgo patrick sebastian',
#  'jefer tarazona',
#  'fernandez vidal jose']

# %%
dict_cobrador = {cobrador: i + 1 if i < 20 else 0 for i , cobrador in enumerate(cobrador_list) }
dict_cobrador
# Out:
# {'olórtegui manrique juan': 1,
#  'fernández monge juan fernando': 2,
#  'vega zúñiga enrique': 3,
#  'oficina provincia': 4,
#  'oficina lima': 5,
#  'saavedra cicirello jose doming': 6,
#  'revolledo humala paulo': 7,
#  'vega ampuero luis carlos': 8,
#  'osorio echevarria roger alcides': 9,
#  'rojas vasquez abner': 10,
#  'escobar salinas miguel': 11,
#  'valle atahuaman toribio': 12,
#  'caceres julca david': 13,
#  'gil zuñiga climaco': 14,
#  'castro elias harol armando': 15,
#  'bravo crisanto david esteban': 16,
#  'alarcon altamirano pepe': 17,
#  'alarcon altamirano mayco': 18,
#  'pepe alarcón': 19,
#  'ponce galindo lady skarlet': 20,
#  'valderrama acuña luisa maria': 0,
#  'quispe tasa william': 0,
#  'torres quiñones luis alberto': 0,
#  'todos': 0,
#  'oficina': 0,
#  'cañas flores alan joel': 0,
#  'cañas flores alan': 0,
#  'rojas vasquez keneth': 0,
#  'huaman jara daniel': 0,
#  'omar velarde durand': 0,
#  'fernandez perez genesis victoria': 0,
#  'vidaurre namuch raul alfredo': 0,
#  'vega ampuero luis': 0,
#  'scarlett ponce galindo': 0,
#  'ponce galindo lady rubi': 0,
#  'ruiz revolledo jose luisxx': 0,
#  'osis alarcon maximo': 0,
#  'ponce rubi': 0,
#  'brsvo crisanto david esteban': 0,
#  'caja oficina lima': 0,
#  'ruiz revolledo jose luis': 0,
#  'revatta escobar rogelio': 0,
#  'vega ganoza jose carlos': 0,
#  'cañas alan': 0,
#  'lupaca castañeda gisela yanet': 0,
#  'apli, notas de abono at': 0,
#  'deposito banco': 0,
#  'ningún vendedor': 0,
#  'apli. notas abono, at y regalo': 0,
#  'aplicacion notas de abono y at': 0,
#  'valdivia hildalgo patrick sebastian': 0,
#  'jefer tarazona': 0,
#  'fernandez vidal jose': 0}

# %%
data['cod_cobrador'] = data.cobrador.map(dict_cobrador)
data
# Out:
#             fecha                              razon_social  \
# 0      2021-01-04              casas sovero daniela yamilet
# 1      2021-01-04              casas sovero daniela yamilet
# 2      2021-01-04                 gc service & parts s.a.c.
# 3      2021-01-05               lopez rosales yolanda juana
# 4      2021-01-06                     palante flotas s.a.c.
# ...           ...                                       ...
# 576016 2024-05-17  empresa de transportes sol de oro s.a.c.
# 576017 2024-05-22     lubricentro virgen del rosario s.r.l.
# 576018 2024-05-22     lubricentro virgen del rosario s.r.l.
# 576019 2024-05-23                     gqr autopartes s.a.c.
# 576020 2024-05-23                     gqr autopartes s.a.c.
#
#                                nombre_articulo       fuente_suministro  \
# 0                             focos h1 12v 55w                   narva
# 1                focos h4 12v 100x90 rallye(7)                   narva
# 2           filtro de aire 1° af25729 055134r1           mann - brasil
# 3       pastillas de freno ceramica d1567 delt      wagner - pastillas
# 4                    aceite sae20w50 sn racing               valvoline
# ...                                        ...                     ...
# 576016               llantas himito nl118 18pr                 deruibo
# 576017        trapecio del lh inf  48069-0k090  ito koyama - trapecios
# 576018        trapecio del rh inf  48068-0k090  ito koyama - trapecios
# 576019         palier 25x23x55 c/anillo ni-214   ito koyama - palieres
# 576020                 copa de palier 23x31x34   ito koyama - palieres
#
#         cantidad  venta_usd  venta_pen        costo  \
# 0           50.0      51.27     185.80   134.870000
# 1          300.0     597.46    2165.20  1413.050100
# 2            8.0     152.54     552.80   310.150000
# 3            2.0      42.36     153.68    96.560000
# 4           90.0     861.86    3129.41  2323.670040
# ...          ...        ...        ...          ...
# 576016      20.0    2796.61   10425.76  7899.060000
# 576017       1.0      59.92     223.68   119.090000
# 576018       1.0      59.92     223.68   118.290000
# 576019       6.0      63.94     239.33   159.430002
# 576020      16.0     202.79     759.04   529.950000
#
#                              cobrador      mes  departamento_num  \
# 0                 vega zúñiga enrique  2021-01               1.0
# 1                 vega zúñiga enrique  2021-01               1.0
# 2                             oficina  2021-01               1.0
# 3              cañas flores alan joel  2021-01               4.0
# 4             olórtegui manrique juan  2021-01               1.0
# ...                               ...      ...               ...
# 576016  fernández monge juan fernando  2024-05               1.0
# 576017   valderrama acuña luisa maria  2024-05               2.0
# 576018   valderrama acuña luisa maria  2024-05               2.0
# 576019            vega zúñiga enrique  2024-05               1.0
# 576020            vega zúñiga enrique  2024-05               1.0
#
#         cod_vendedor  cod_razon_social  cod_cobrador
# 0                 13                 0             3
# 1                 13                 0             3
# 2                 28                 0             0
# 3                 21                 0             0
# 4                 30                 0             1
# ...              ...               ...           ...
# 576016            22                 0             2
# 576017             0                 0             0
# 576018             0                 0             0
# 576019            24                 0             3
# 576020            24                 0             3
#
# [576021 rows x 14 columns]

# %%
nombre_articulo_list = list(data.nombre_articulo.value_counts().index)
nombre_articulo_list[:20]
# Out:
# ['filtro sep de agua(6)lfwp9000 fs19532',
#  'focos 1034 2 cont p21/5w',
#  'amortiguador del rh',
#  'amortiguador del lh',
#  'filtro de petroleo(50)8-98162-897-0',
#  'filtro de petroleo(25)1457434310',
#  'focos 93 1 cont 1141 p21w',
#  'kit de filtros(1)1º2º a-1325+a-1330',
#  'amortiguador post rh lh',
#  'focos h4 60x55w p43t-38',
#  'filtro sep de agua(6)ps6643 fco553a',
#  'filtro de aceite(50)fco515 lf3007 lf3537',
#  'filtro de petroleo(25)8-98092481-1',
#  'focos 158 lagri mediana w5w',
#  'aceite sae5w30 sn synthetic glx1.25gl 5/4',
#  'aceite sae10w30 sn semi sintetico',
#  'aceite aw68 prextofluid iso68 ambar',
#  'filtro de aceite(6)lf7205 lf3818',
#  'focos 67 r5w',
#  'kit de filtros(9)1° 2° a-5541+a-5540 af25692']

# %%
nombre_articulo_dict = {nombre_articulo: i + 1 if i < 20 else 0 for i, nombre_articulo in enumerate(nombre_articulo_list)}
nombre_articulo_dict
# Out:
# {'filtro sep de agua(6)lfwp9000 fs19532': 1,
#  'focos 1034 2 cont p21/5w': 2,
#  'amortiguador del rh': 3,
#  'amortiguador del lh': 4,
#  'filtro de petroleo(50)8-98162-897-0': 5,
#  'filtro de petroleo(25)1457434310': 6,
#  'focos 93 1 cont 1141 p21w': 7,
#  'kit de filtros(1)1º2º a-1325+a-1330': 8,
#  'amortiguador post rh lh': 9,
#  'focos h4 60x55w p43t-38': 10,
#  'filtro sep de agua(6)ps6643 fco553a': 11,
#  'filtro de aceite(50)fco515 lf3007 lf3537': 12,
#  'filtro de petroleo(25)8-98092481-1': 13,
#  'focos 158 lagri mediana w5w': 14,
#  'aceite sae5w30 sn synthetic glx1.25gl 5/4': 15,
#  'aceite sae10w30 sn semi sintetico': 16,
#  'aceite aw68 prextofluid iso68 ambar': 17,
#  'filtro de aceite(6)lf7205 lf3818': 18,
#  'focos 67 r5w': 19,
#  'kit de filtros(9)1° 2° a-5541+a-5540 af25692': 20,
#  'amortiguador del rh lh': 0,
#  'filtro de petroleo(25)w-950/14 fco525': 0,
#  'focos h4 12v 100x90 rallye(7)': 0,
#  'filtro de petroleo(50) me-195160': 0,
#  'kit de filtros(4)1°2° a-5539+a-5538': 0,
#  'filtro de aceite(50)per4476 lf3001': 0,
#  'filtro de petroleo(25)23304-ev030': 0,
#  'filtro de petroleo(25)fco526 lfp356': 0,
#  'focos h7 12v 55w': 0,
#  'filtro de aceite(12)fco520a lf604a lf16227': 0,
#  'filtro de petroleo(50)lp9010': 0,
#  'aceite sae15w40 ci4 prextodiesel hd': 0,
#  'transf. a titulo gratuito sakura': 0,
#  'kit de filtros(4)1°2° a-1324+a-1326': 0,
#  'kit de filtros(1)1° 2° a-6036+a-6037': 0,
#  'filtro de aceite(10)lf9713 lf3854': 0,
#  'silicona gris c/blister 85gr': 0,
#  'filtro de aire(4)af27693 afl2234hdr': 0,
#  'aceite sae20w50 sn racing': 0,
#  'refrig verde 33% mescla precisa gln': 0,
#  'filtro de aceite(50)26311-52001 ox378': 0,
#  'filtro de aire(4)af17801': 0,
#  'filtro de aceite(50)b160 ph10060': 0,
#  'filtro sep de agua(25)p502426 lp2178 ep140': 0,
#  'focos h7': 0,
#  'resorte post ref 12.7x120x333x8 3590': 0,
#  'aceite sae10w30 sn synthetic glx1.25gl 5/4': 0,
#  'focos h4 (7) rallye': 0,
#  'filtro de petroleo(12)ff5734': 0,
#  'resorte post gnv 12.2x124x332x7 8493': 0,
#  'filtro de aceite(50)': 0,
#  'filtro de petroleo(50)lpf78020 pp431': 0,
#  'filtro de petroleo(50)23304-ev390': 0,
#  'filtro de aire(1)af10250 afl1207': 0,
#  'filtro de petroleo(50)23390-0l070': 0,
#  'filtro de aire(20)17801-0l040 af3740': 0,
#  'filtro de aire(20)afl040 afp5165 17801-04050': 0,
#  'filtro de aceite per67 lf667 466634 lf3321 lf67': 0,
#  'resorte del ref 12.7x140x335x5 3/4 9542': 0,
#  'kit de filtros(12)1° 2° a-8506+a-8565': 0,
#  'focos h4': 0,
#  'filtro de petroleo(12)pc42 lfp42 466987': 0,
#  'filtro de cabina a/c(20) afc5202': 0,
#  'focos h3': 0,
#  'filtro sep de agua(12)fs19532 s/vaso': 0,
#  'focos h4 w5w rpw 2 pzas(7)': 0,
#  'amortiguador del rh 334472': 0,
#  'focos w21/5w 2 cont lagrimon': 0,
#  'amortiguador del lh 334473': 0,
#  'kit de filtros(25)1° 2° a-8513+a-5569': 0,
#  'kit de filtros(1)1° 2° a-7122+a-7128***300': 0,
#  'resorte del ref gnv 11.7x127x395x6 3/8 14913': 0,
#  'resorte post ref 12.7x98x315x6 3/8 10364': 0,
#  'filtro de cabina(20)87139-0k060': 0,
#  'resorte del ref 12.2x144x390x5 3/4 9160': 0,
#  'filtro de petroleo(50)lfp1334 ff5451': 0,
#  'amortiguador del rh lh b2350': 0,
#  'resorte del ref 17.2x111x365x9 3/8 9670': 0,
#  'filtro de aire(20)afl098 1500a098': 0,
#  'disco de embrague 200x140x21d': 0,
#  'filtro de aceite(36)per17 lf27 lf3311=c-1122': 0,
#  'filtro de aceite(6)1-87610189-0': 0,
#  'focos h3 rallye': 0,
#  'resorte del ori 12.2x141x365x6 491': 0,
#  'filtro de petroleo(25)fco521 lfp521nx': 0,
#  'aceite sae20w50 sn semi sintetico': 0,
#  'filtro de aceite(6)15208-89tb2': 0,
#  'kit de filtros1° 2°(25)a-8505+a-8599': 0,
#  'focos h1 12v 55w': 0,
#  'filtro de petroleo(25)16403-4kv0a': 0,
#  'transf. a titulo gratuito valvoline': 0,
#  'aceite sae15w40 ci4 plus/sl': 0,
#  'focos e74 lagrimita de tab (7)': 0,
#  'transf. a titulo gratuito koyama': 0,
#  'kit de filtros(1)1º 2º a-5440+a-5439': 0,
#  'bujia de encendido 3194 solido': 0,
#  'filtro de aire(8)afp5155 afl4810hd': 0,
#  'filtro de gas turbo(50)': 0,
#  'filtro de aceite(50)per241 lf80 ph3614': 0,
#  'filtro de petroleo(32)': 0,
#  'disco de embrague 275x175x21d': 0,
#  'amortiguador post rh lh 343442': 0,
#  'refrig rojo 50/50 hd comand': 0,
#  'resorte post gnv 12.2x122x370x7 7/8 6241': 0,
#  'resorte del ref 11.7x142x330x5 3/8 465': 0,
#  'filtro de aceite(12)j8610898': 0,
#  'filtro de cabina(20) 97133-2e200 afc97133': 0,
#  'resorte post ref 12.2x140x340x6 493': 0,
#  'filtro sep de agua(6)3989632 lfwp8512': 0,
#  'focos h3 12v 55w(5)': 0,
#  'resorte del ref 13x155x385x5 3/4 447': 0,
#  'filtro de aire(20)afl21050 ca10190': 0,
#  'filtro de aceite(25)fco520 lf604 d/f': 0,
#  'resorte post ref 11.2x95x335x8 7/8 467': 0,
#  'filtro de petroleo(12)me306306 me-301897': 0,
#  'filtro sep de agua(6)lfwp9012nx 33788': 0,
#  'focos h11 12v 55w(1)': 0,
#  'disco de embrague': 0,
#  'filtro de aire(20)af1880 afl2169': 0,
#  'resorte post ref 12.7x123x325x7 3/8 10550': 0,
#  'bujia de encendido 3120 solido': 0,
#  'resorte del ori 13x151x350x4 5/8 10222': 0,
#  'focos hb3 9005': 0,
#  'filtro de aceite(50)per241 lf80 ph3614 lf3460': 0,
#  'collarin de embrague': 0,
#  'resorte del ori 12.8x153x355x5 1/4 496': 0,
#  'aceite sae5w30 sn synthetic 1/4': 0,
#  'filtro de aire(20)c-21015/1': 0,
#  'aceite sae80w90 gl-5': 0,
#  'focos h1=48708': 0,
#  'filtro sep de agua(6)kc125/1 fs20028': 0,
#  'focos 1 cont py21w ambar (7)': 0,
#  'filtro de aire(4)af10293 afl5500hd': 0,
#  'resorte del ref 10.5x101x330x7 7/8 67': 0,
#  'kit de filtros 1°2°(1)a-5801+a-5805': 0,
#  'aceite sae10w30 sn racing': 0,
#  'filtro de aceite(16)lf3478 lf734 per213': 0,
#  'filtro de aceite(50)per286 lf109': 0,
#  'focos h4 rpw 2 pzas(7)': 0,
#  'filtro de petroleo(12)lfp3192nx': 0,
#  'filtro de aire(4)u2y0-12-z40': 0,
#  'resorte post ori 11.7x114x295x7 3/8 9841': 0,
#  'filtro de aceite bypass lf3654 477556': 0,
#  'disco de embrague 236x150x21d': 0,
#  'resorte post ref 13.7x131x380x8 1/4 483': 0,
#  'amortiguador del rh lh 333258': 0,
#  'disco de embrague 215x140x21d': 0,
#  'liquido de freno dot3 12 onzas lata': 0,
#  'focos 921 lagri mediana w16w(5)': 0,
#  'disco de embrague 260x170x21d': 0,
#  'resorte post gnv 11.7x105x368x8 1/2 6331': 0,
#  'resorte del ref 13.2x162x340x4 1/4 8751': 0,
#  'resorte del ref 13x144x340x6 1/4 8752': 0,
#  'plato de embrague': 0,
#  'amortiguador del lh 339131': 0,
#  'focos led h4 rpl2 12v 24v 21w 6500k': 0,
#  'amortiguador del rh 339130': 0,
#  'bomba de embrague 5/8': 0,
#  'filtro de petroleo(20)hdf-962': 0,
#  'filtro de petroleo(10)1429059': 0,
#  'transf. a titulo gratuito ikoyama': 0,
#  'filtro de aceite(50)8-98018858-0': 0,
#  'filtro de petroleo(12) 31922-4h001': 0,
#  'filtro de gas turbo(100)8-98002346-0': 0,
#  'plato de embrague 239x149x264': 0,
#  'filtro de aceite(75)w-75/2 per583': 0,
#  'filtro de aceite(12)15604-22050 s/tuerca': 0,
#  'filtro de aceite(50)hu-945/2x lf3914': 0,
#  'resorte post ref 15.2x144x295x6 3262': 0,
#  'resorte post ref 12.2x151x350x5 7/8 449': 0,
#  'filtro de petroleo 20430751 20976003 ff5507': 0,
#  'filtro de aire(20)': 0,
#  'amortiguador del rh lh 341372': 0,
#  'filtro de aceite(50)per4477 lf3005 p502019': 0,
#  'amortiguador post rh lh e20045': 0,
#  'formador de empaques 130gr 24 unidades': 0,
#  'filtro de petroleo(6)pf7761 ff5405': 0,
#  'resorte del ref 13.2x151x335x5 1/4 3437': 0,
#  'resorte del ori 11.7x100x320x8 3/4 7305': 0,
#  'filtro de aceite(6)bd7141 lf3850': 0,
#  'filtro de aceite(12)s15160-72320 c/tuerca': 0,
#  'kit de filtros(1)1º 2º a-5549+a-5550': 0,
#  'disco de embrague 200mm': 0,
#  'filtro de aceite(50)986af0035 25181616': 0,
#  'filtro de aceite(25)per1a lf1a ph8a': 0,
#  'resorte del ori 12.2x134x345x5 1/2 8783': 0,
#  'kit de filtros(1)1° 2° a-6303+a-5311': 0,
#  'filtro de hidrolina(24)p23 l98 349619': 0,
#  'filtro de aceite(50)ch10358': 0,
#  'plato de embrague 275x170x298': 0,
#  'focos hb4 9006 (5)': 0,
#  'resorte post gnv 13.2x89x270x5 1/2 5358': 0,
#  'filtro de aire(20)1500a608': 0,
#  'filtro de petroleo(50)ff5380 pu-1046/x': 0,
#  'filtro de petroleo(6)pu-1046/1x pf7735': 0,
#  'resorte del ori 12.7x133x315x8 5/8 10418': 0,
#  'amortiguador del rh 338096': 0,
#  'filtro de aceite(50)per4622 lf3006': 0,
#  'aceite sae25w60 sl maxpower': 0,
#  'filtro secador de aire(6)tb-1374x': 0,
#  'resorte post gnv 12.2x107x340x8 3/4 11079': 0,
#  'transf. a titulo gratuito ishikawa': 0,
#  'filtro de petroleo(6)fco550 8193841': 0,
#  'resorte post ref 11.7x108x330x6 7/8 495': 0,
#  'resorte del ori 13.7x166x330x5 6180': 0,
#  'kit de embrague ct-011u+dt-123v': 0,
#  'amortiguador del lh 338097': 0,
#  'filtro de petroleo(50)mx914625': 0,
#  'pastillas de freno ceramica del d976': 0,
#  'plastigage rojo 12 unidades': 0,
#  'filtro secador de aire 3090288': 0,
#  'refrig rojo 50/50 hd gln zerex rtu afc': 0,
#  'filtro de petroleo(50)23304-ev360': 0,
#  'resorte post ref 12.5x124x335x7 3322': 0,
#  'disco de freno delt vent bd4113  318.8x28x67.2x108x6': 0,
#  'filtro de aceite(100) 57262': 0,
#  'filtro de cabina(20)27275-0n025': 0,
#  'filtro de aire(4)28113-4f000***800': 0,
#  'kit de filtros(4)1°2° a-1126+a-1155': 0,
#  'plato de embrague 200mm': 0,
#  'amortiguador post rh lh 443241': 0,
#  'plato de embrague 203x137x237': 0,
#  'focos 7505 1 cont lagrimon ambar': 0,
#  'focos h1 rallye': 0,
#  'amortiguador del lh 333210': 0,
#  'liquido de freno dot4 12 onzas plastico': 0,
#  'bujia de encendido 3179': 0,
#  'resorte post ref 13.2x103x345x9 1/2 9471': 0,
#  'resorte post gnv 13.7x109x340x8 5/8 7802': 0,
#  'filtro de aire 1° 20544738 af26242': 0,
#  'filtro de petroleo(25) lfp305 ps4922***950': 0,
#  'amortiguador del lh 54650-1r001': 0,
#  'filtro sep de agua(6)fs19769 s/vaso': 0,
#  'palier 26x22x55.5': 0,
#  'resorte post gnv 13.2x111x295x6 7/8 662': 0,
#  'palier 25x23x55 c/anillo ni-214': 0,
#  'kit de filtros(1)1° 2° a-7101+a-7102': 0,
#  'filtro de aceite(50)lf3827': 0,
#  'filtro de cabina(20)': 0,
#  'refrig verde 33% zerex afc mescla precisa': 0,
#  'amortiguador del rh 54660-1r001': 0,
#  'amortiguador del rh 633115': 0,
#  'filtro de aceite(50)l10193 lf260': 0,
#  'plato de embrague 239x149x271': 0,
#  'amortiguador del rh 333209': 0,
#  'palier 25x22x50 c/anillo': 0,
#  'amortiguador del lh 633116': 0,
#  'terminal del ext lh 45047-09370 cet-201l': 0,
#  'resorte post ref 13.7x162x270x7 1/4 65': 0,
#  'terminal del ext rh 45046-09720 cet-201r': 0,
#  'focos h7 rpw 2 pzas': 0,
#  'palier 26x24x56 c/anillo to-2015': 0,
#  'amortiguador del lh 54651-3x250': 0,
#  'filtro sep de agua(12)fco211***240': 0,
#  'resorte del ref 14.7x166x305x4 3/4 12586': 0,
#  'filtro de gasolina(32)16400-es60a': 0,
#  'aceite sae10w hidraulico cf/sf': 0,
#  'focos 7505 1 cont lagrimon': 0,
#  'aceite aw68 prextofluid iso68 rojo': 0,
#  'rack end del rh lh 45503-0k130': 0,
#  'resorte post ref 11.2x101x295x6 3/4 5121': 0,
#  'filtro de aire(20)c-2201 a35592 af3984 afl4609': 0,
#  'filtro de aceite(25)lf601 b7045 lf3689': 0,
#  'palier 26x23x56 c/anillo to-2014f2': 0,
#  'resorte post ref 11.7x101x360x11 7/8 64': 0,
#  'refrig rojo 50/50 af lln toyota gln': 0,
#  'filtro de aceite lf16046 p7230 p550769': 0,
#  'filtro de aceite(50)90905-20003 ph3614 lf3460': 0,
#  'amortiguador del rh 54661-3x250': 0,
#  'resorte post ref 15x107x320x6 1/2 9079': 0,
#  'filtro de aceite(6)fco549 lf4013': 0,
#  'kit de filtros 1°2°(1)a-58410+a-58420': 0,
#  'filtro de cabina a/c(20)': 0,
#  'aceite sae20w50 sl gas power': 0,
#  'filtro de aire(9)af3125 afl6903hd': 0,
#  'resorte del ori 11x114x365x5 5/8 1104dd': 0,
#  'palier 25x21x52.5 c/anillo hy-230': 0,
#  'amortiguador post rh lh 343295': 0,
#  'focos led h7 rpl2 12v 24v 24w 6500k': 0,
#  'estabilizadores del rh 48820-0k030 clt-45': 0,
#  'focos 1 cont py21whd ambar(7)': 0,
#  'filtro de aceite(6) bt7116 lf3506': 0,
#  'liquido de freno dot3 12 onzas plastico': 0,
#  'filtro de aceite(50) l15839 55594652': 0,
#  'resorte del ori 16.7x110x365x9 1/2 5592': 0,
#  'estabilizadores del lh 48810-0k010 clt-46': 0,
#  'plato de embrague 263x168x298': 0,
#  'filtro de cabina(20) 97133-2h001': 0,
#  'amortiguador post rh': 0,
#  'filtro de aire(20)mr-968274 ca10910': 0,
#  'amortiguador post lh': 0,
#  'disco de embrague 224x150x20d': 0,
#  'amortiguador del rh lh 665021': 0,
#  'amortiguador post rh lh 341191': 0,
#  'resorte post ref 12.2x141x370x6 1/2 460': 0,
#  'resorte post gnv 15x84x275x6 1/4 11760': 0,
#  'palier 26x23x58 c/anillo': 0,
#  'resorte post gnv 11.5x77x320x8 17218': 0,
#  'filtro de aire(9)afp5151 afl9501hd': 0,
#  'palier 30x29x72.5 c/anillo to-210': 0,
#  'kit de filtros(1)1°2° a-1013+a-5631': 0,
#  'transf. a titulo gratuito mann': 0,
#  'filtro de aceite(50)ch6848 l44757 l810': 0,
#  'kit de filtros(1)1° 2° a-5328+a-5329': 0,
#  'pegamento epoxico 4min acero 2 oz 57gr': 0,
#  'filtro de aire(20)afl1134': 0,
#  'estabilizadores del rh lh 42420-61j00': 0,
#  'amortiguador del rh 3330083': 0,
#  'liquido de freno dot4 8.45 onzas lata': 0,
#  'aceite syntetic cvt fluid 1/4': 0,
#  'novarundum 120gr 007 24 unidades': 0,
#  'filtro de aceite(12)l45262 lf9604 c/valvula': 0,
#  'plastigage verde 12 unidades': 0,
#  'palier 24x20x52.5 c/anillo hy-232': 0,
#  'aceite sae15w40 ci4 plus': 0,
#  'filtro de aire(20) 13780-74l00': 0,
#  'focos 715 taw de tablero bala': 0,
#  'amortiguador del lh 3330084': 0,
#  'resorte del ori 11.5x112x340x7 1/2 12755': 0,
#  'resorte del ori 17.7x201x355x4 6400': 0,
#  'aceite sae85w140 gl-5': 0,
#  'kit de filtros(1)1° 2° a-57250+a-57260': 0,
#  'filtro de aceite(50)68191349aa': 0,
#  'terminal del rh lh 45046-09800': 0,
#  'filtro sep de agua(10)fs1287': 0,
#  'filtro sep de agua(12)r90tdmax wk-11001x': 0,
#  'resorte del ori 16.7x111x365x5 1/2 6829': 0,
#  'amortiguador post rh lh 341194': 0,
#  'kit de filtros(1)1º2º a-5023+a-5024': 0,
#  'aceite sae5w30 sn synthetic': 0,
#  'filtro de aire 1° af25721': 0,
#  'amortiguador del rh 333417': 0,
#  'resorte del ori 11.7x131x315x8 3/4 9315': 0,
#  'tambor de freno s/cubo bd4212  344.5x76.1x108x6': 0,
#  'filtro de aire(20)afl1304 fa3040': 0,
#  'filtro de aire(20)16546-1hk0a': 0,
#  'amortiguador del lh 332153': 0,
#  'amortiguador del lh 333418': 0,
#  'amortiguador post rh lh 341363': 0,
#  'filtro de aceite(50)12636838': 0,
#  'amortiguador del rh lh 333741': 0,
#  'kit de filtros(1)1° 2° a-8577+a-8578': 0,
#  'filtro de aire(20)afl1100 fa1131': 0,
#  'amortiguador del lh 339032': 0,
#  'amortiguador del rh 332152': 0,
#  'focos 3157na c/base negro ambar(5)': 0,
#  'resorte del ori 13.2x140x325x5 1/4 13128': 0,
#  'aceite atf dexron iii': 0,
#  'amortiguador del rh 333114-re': 0,
#  'kit de filtros 1°2°(12)as-5628+a-7611 c/d': 0,
#  'resorte del ref 12.7x139x310x6 1/4 66': 0,
#  'resorte del ori 13.5x130x305x5 14264': 0,
#  'liquido de freno dot3  8 onzas lata': 0,
#  'kit de filtros(1)1º 2º a-5443+a-5442': 0,
#  'palier 25x22x52.4 c/abs': 0,
#  'palier 23x23x56 c/anillo to-2007': 0,
#  'palier 26x32x58 c/abs': 0,
#  'amortiguador post rh lh 341279': 0,
#  'filtro de aceite(12)per17 lf27 lf3311=c-1903': 0,
#  'amortiguador del rh 339031': 0,
#  'amortiguador del lh 332117': 0,
#  'amortiguador del lh 333115-re': 0,
#  'resorte del ref 13.2x142x315x5 1/4 10781': 0,
#  'palier 25x29x49 c/anillo sk-823a': 0,
#  'kit de filtros(1)1°2°a-5331+a-26360': 0,
#  'palier 25x22x49  ni-232': 0,
#  'amortiguador del rh 332116': 0,
#  'resorte del ref 12.5x141x380x6 5/8 499': 0,
#  'filtro de aceite(50)lf3335 per241 lf80': 0,
#  'rotula del sup rh lh 43310-09015 cbt-63': 0,
#  'resorte post ori 11.7x111x360x7 1/2 11420': 0,
#  'amortiguador del rh 24526127r': 0,
#  'amortiguador del lh 24526127l': 0,
#  'aceite sae5w40 sn synthetic mst glx1.25gl 5/4': 0,
#  'amortiguador del rh 54660-1y200': 0,
#  'resorte del ori 12.2x98x375x11 1/2 73': 0,
#  'filtro de aceite(50)pp410 l2200': 0,
#  'filtro de aceite(50)per111 lf111 96879797': 0,
#  'pasta azul de prusia 18gr 35v 24 unidades': 0,
#  'filtro de aceite(12)ph2 b239 lf3681***960': 0,
#  'rotula del inf rh lh 54530-0u000 cbkh-38': 0,
#  'amortiguador post rh lh 55300-1m300': 0,
#  'filtro de petroleo(25)pu-999/1x ff5405': 0,
#  'resorte post ref 16x147x285x5 16590': 0,
#  'kit de filtros(1)1° 2° a-71400+a-71410': 0,
#  'filtro de aire(20)af4278 afl462***700': 0,
#  'amortiguador del lh 333115': 0,
#  'filtro de aceite lf3914 p7188 p550761': 0,
#  'filtro de cabina(20) 19315267': 0,
#  'filtro sep de agua(25)sfc-5115': 0,
#  'rotula del inf rh lh 43330-09295 cbt-64': 0,
#  'palier 30x36x73 c/abs': 0,
#  'amortiguador del lh 54650-1y200': 0,
#  'resorte post glp 12.7x102x345x9 9281': 0,
#  'bomba de aceite 15100-64042': 0,
#  'filtro de petroleo(25)lfp6403 pfc3182': 0,
#  'kit de filtros 1°2°(1)a-76520+a-76510': 0,
#  'kit de filtros(1)1°2° a-22370+a-22360': 0,
#  'palier 25x22x55 c/anillo ni-2020': 0,
#  'terminal del ext lh 56820-0u500 cekh-46l': 0,
#  'resorte post gnv 12.5x79x340x8 1/2 15157': 0,
#  'filtro de aire(20) a45650 afl3112': 0,
#  'amortiguador del rh 333114': 0,
#  'resorte post ref 11.7x122x300x6 3/4 9787': 0,
#  'filtro de aire(4)af10250 afl1207': 0,
#  'amortiguador del rh lh 340033': 0,
#  'amortiguador del rh 334464': 0,
#  'resorte del ori 12x116x330x6 1/2 16342': 0,
#  'filtro de petroleo(6)ff5297 1372444': 0,
#  'palier 30x35x69 c/abs mi-318': 0,
#  'filtro de aceite(50) ch9018 e630h': 0,
#  'amortiguador post rh lh 55300-3x100': 0,
#  'kit de filtros(1)1° 2° a-5558+a-5559': 0,
#  'filtro de aire 2° af25722': 0,
#  'filtro sep de agua(6)2r0127177 fs1105': 0,
#  'resorte post gnv 10x101x280x7 11350': 0,
#  'filtro de aire(20)28113-2s000 afl1132': 0,
#  'amortiguador del lh 334465': 0,
#  'terminal del ext rh 56820-0u590 cekh-46r': 0,
#  'llantas deestone 120/117q r408 10pr': 0,
#  'kit de filtros(1)1°2° a-38050+a-38040': 0,
#  'resorte post ori 14.2x186x370x6 1/2 10324': 0,
#  'filtro de petroleo(50)wk-723 pc42 lfp42': 0,
#  'amortiguador del rh 338094': 0,
#  'resorte del ref 10.7x107x325x8 9842': 0,
#  'refrig rosado 50/50 audi vw europeros gln': 0,
#  'rotula del inf rh lh 43330-19095 cbt-40': 0,
#  'amortiguador del rh lh 377412503': 0,
#  'resorte post glp 13.5x132x315x5 3/8 11446': 0,
#  'estabilizadores del lh 54830-1g000 clkk-28l': 0,
#  'amortiguador del lh 338095': 0,
#  'rotula del inf rh lh 43308-59035 cbt-56': 0,
#  'palier 26x31x55.6  to-200': 0,
#  'filtro de aceite(12)15208-89tb3 ph2953a': 0,
#  'resorte post ref 12.2x118x383x8 92': 0,
#  'filtro de cabina(20) ucy0-61-p11': 0,
#  'estabilizadores del rh 54840-1g000 clkk-28r': 0,
#  'amortiguador post rh lh 343423': 0,
#  'focos fusible salon 10x31(5)': 0,
#  'focos 715 t4w de tablero bala': 0,
#  'aceite atf maxlife dex/merc dexron iii 1/4': 0,
#  'resorte post gnv 15.2x118x300x6 1/2 667': 0,
#  'amortiguador post rh lh 341281': 0,
#  'resorte post gnv 4 13x124x340x8 16469': 0,
#  'filtro de aire(12)pa3833 af25477': 0,
#  'resorte post ref 11.5x80x315x7 11513dp': 0,
#  'filtro de petroleo(50)': 0,
#  'resorte del ori 13.5x133x290x5 1/2 1352md': 0,
#  'resorte post ref 14.7x135x315x5 1/4 11925': 0,
#  'palier 25x29x49 s/abs': 0,
#  'filtro de aceite per2168 pc211b lf398': 0,
#  'aceite sae0w20 sn synthetic 1/4': 0,
#  'focos baxgris c/base de tab5d (5)': 0,
#  'filtro de aire 1°(1)af10289 afl3821hdr': 0,
#  'filtro de aire 1° af25729 055134r1': 0,
#  'focos 158 lagri mediana': 0,
#  'filtro de aceite(50)b1446 lf3786 ph5203 lf5512': 0,
#  'filtro de aire(20)af7964 afl1030': 0,
#  'palier 30x29x70 c/anillo': 0,
#  'rack end del rh lh 45503-09321 crt-89': 0,
#  'amortiguador del lh 54660-4h600': 0,
#  'amortiguador post rh lh 377513029': 0,
#  'palier 22x29x52 c/anillo': 0,
#  'filtro de petroleo(12) p502466 fco110***300': 0,
#  'resorte del ori 12.7x151x360x5 1/2 8941': 0,
#  'amortiguador post rh lh 341322': 0,
#  'kit de filtros(9)1° 2° a-6207+a-6302': 0,
#  'filtro de aceite(50)fco19 lf916 lf3434***1,500': 0,
#  'manguera de aire rojo azul 15ft': 0,
#  'resorte post gnv 11.5x79x320x7 17471': 0,
#  'resorte del ori 13x126x325x5 1/2 14475': 0,
#  'filtro de aceite(50)ch10158': 0,
#  'estabilizadores del rh lh 48820-0d020 clt-69': 0,
#  'transf. a título gratuito valvoline': 0,
#  'focos h1 rpw 2 pzas': 0,
#  'radiador mt version 16400-0l451': 0,
#  'resorte post ref 11.7x101x355x8 1/2 518': 0,
#  'amortiguador del lh 333432': 0,
#  'rotula del inf del rh lh 54530-2k000 cbkk-27': 0,
#  'amortiguador del rh 333431': 0,
#  'filtro de aire(20)16546-4ba1a': 0,
#  'focos led hb3 hb4 rpl2 12v 24v 6500k': 0,
#  'grasa roja de calcio balde nlgi-2': 0,
#  'amortiguador del lh 334324': 0,
#  'kit de filtros(1)1° 2° a-6119m+a-6120m': 0,
#  'amortiguador del rh 334323': 0,
#  'filtro de aire(9)af10347 afl23603': 0,
#  'transf. a titulo gratuito aisin': 0,
#  'filtro de aire 1°(25)p812543 rs3704': 0,
#  'palier 26x32x55.4 c/abs to-257a48t': 0,
#  'filtro de aire(20)afp5138 afl2016***800': 0,
#  'amortiguador del rh 3340047': 0,
#  'resorte post ref 13.2x103x320x9 13715': 0,
#  'filtro de petroleo(25)fco502 lfp829': 0,
#  'amortiguador post rh lh 349017': 0,
#  'filtro de aceite caja per18a lf19': 0,
#  'aceite atf dexron vi 1/4': 0,
#  'filtro de cabina(20)7803a112': 0,
#  'amortiguador post rh 632072': 0,
#  'focos 3157 c/base negro (5)': 0,
#  'filtro de aceite(50)w-712/52 lf155 c/tuerca': 0,
#  'palier 24x23x58 s/abs': 0,
#  'bujia de encendido 3027': 0,
#  'terminal del ext rh 45046-59195 cet-166': 0,
#  'resorte post ref 12.2x122x280x5 5/8': 0,
#  'amortiguador del rh 54650-4h600': 0,
#  'resorte del ori 11.5x115x340x6 1/8 11903': 0,
#  'filtro de cabina(20)97133-07010***200': 0,
#  'filtro de aceite(50)hu-718/1k': 0,
#  'filtro de aire(20) afl866 a25801': 0,
#  'kit de filtros(4)1º 2º a-2210+a-6008': 0,
#  'resorte del ori 13.4x172x388x5': 0,
#  'palier 27x25x62.2  hy-825': 0,
#  'terminal del ext lh 45047-59135 cet-167': 0,
#  'filtro de aceite 2037556 2022275 lf17486': 0,
#  'filtro de cabina(20)97133-3saa0 19334598': 0,
#  'kit de filtros(1)1º 2º a-8508+a-8507***600': 0,
#  'palier 27x26x60 c/anillo': 0,
#  'filtro de aire(6)af10300 afl2813hd': 0,
#  'kit de filtros(9)1°2° a-88220+a-88210': 0,
#  'amortiguador post lh 632073': 0,
#  'estabilizadores del rh 54840-1j000 clkh-43r': 0,
#  'filtro de aceite lf3827': 0,
#  'filtro de aceite(50)w-719/5 c/valvula': 0,
#  'kit de embrague dtx-232a+ctx-170z': 0,
#  'filtro de aceite(6)bypass per4519 lf3000': 0,
#  'resorte del ori 12.7x144x345x5 1/2 13706': 0,
#  'filtro de petroleo(50)pu-1059x***300': 0,
#  'amortiguador post rh lh 349024': 0,
#  'amortiguador del lh 339401': 0,
#  'estabilizadores del lh mr992309 clm-25': 0,
#  'palier 22x30x50': 0,
#  'amortiguador del lh 3340048': 0,
#  'filtro de agua(12)1699830 20532237 wf2096': 0,
#  'palier 27x30x56 c/anillo': 0,
#  'filtro de aceite(50)1109.z2 ch10066***400': 0,
#  'amortiguador post rh 333116': 0,
#  'pastillas de freno ceramica d976 delt': 0,
#  'rache de freno 10d 3h 351595 278323': 0,
#  'focos h7 12v rallye': 0,
#  'filtro de petroleo c/sensor kl912': 0,
#  'resorte del ref 15.2x177x340x5 9077': 0,
#  'filtro de petroleo(25)me-132525': 0,
#  'estabilizadores del rh mr992310 clm-24': 0,
#  'filtro de aire(20)ca3997': 0,
#  'amortiguador del rh 339400': 0,
#  'amortiguador post lh 333117': 0,
#  'palier 25x21x49  ni-231': 0,
#  'estabilizadores del lh 54830-1j000 clkh-43l': 0,
#  'amortiguador post rh lh 343435': 0,
#  'filtro de aire(20)17801-30040***200': 0,
#  'aceite tractofluid uthf303': 0,
#  'resorte del ref 12.7x144x345x5 8297': 0,
#  'filtro de petroleo(25)mx910095***800': 0,
#  'resorte post gnv 5 13.5x83x305x6 1/2 13987': 0,
#  'filtro de aire 1° af25723 055129r1 rs3992': 0,
#  'resorte post ori 11.2x101x378x10 1/2 74': 0,
#  'trapecio del lh sup   48630-0k040': 0,
#  'liquido de freno dot3 1lt 32 oz 946ml plastico': 0,
#  'filtro de cabina(20)19280716': 0,
#  'refrig azul 50/50 zerex rtu afc asian': 0,
#  'trapecio del rh sup  48610-0k040': 0,
#  'palier 23x19x44 s/ext op-2010': 0,
#  'filtro de aire(1)8-98321413-0': 0,
#  'torreta del 48609-12270': 0,
#  'resorte del ref 17.7x128x315x6 5/8 13457': 0,
#  'palier 23x19x49 c/anillo sk-024': 0,
#  'filtro de aire(4)af10350 afl7803hdr': 0,
#  'rotula del inf rh lh 51760-1g000 cbkk-20': 0,
#  'resorte post glp 12.5x79x290x6 1/4 13116': 0,
#  'disco de embrague 190mm': 0,
#  'llantas deestone 97/95p r406 12pr': 0,
#  'palier 27x22x60 c/abs': 0,
#  'focos h8 12v 35w(1)': 0,
#  'liquido de freno dot4 1lt 32 onzas plastico': 0,
#  'palier 24x22x52 c/anillo ni-2003': 0,
#  'plato de embrague 218x137x250': 0,
#  'amortiguador del rh lh 5u0413031': 0,
#  'resorte del ref 14.2x126x390x8 3/4 5727': 0,
#  'filtro de petroleo(50)fco900 lfp2290n': 0,
#  'filtro de petroleo(12) 23304-ev150': 0,
#  'aceite sae30w transmision to-4': 0,
#  'filtro de petroleo(50)lfp150nx hdf-296': 0,
#  'rotula del inf rh lh 54530-3j000 cbkk-22': 0,
#  'amortiguador del lh 90904863': 0,
#  'filtro de cabina(20)27277-4bu0a': 0,
#  'terminal del ext rh lh 45046-09281 cet-147': 0,
#  'filtro de aire(20)ca8997 ca9055': 0,
#  'filtro de aire 1º 8149064 af25631': 0,
#  'terminal del rh lh 48810-60810 se-7561': 0,
#  'resorte post gnv 11.7x101x370x9 1/2 533': 0,
#  'resorte post ori 18.8x162x340x6 6335': 0,
#  'filtro de aire(12)af10263 afl6201hd': 0,
#  'amortiguador del rh 90904862': 0,
#  'llantas deestone 88/86p r406 10pr': 0,
#  'amortiguador del lh 333516': 0,
#  'filtro sep de agua(12)3890548 036530r1 psd530/1': 0,
#  'palier 25x23x55 c/anillo ni-2022f3': 0,
#  'disco de ambrague 215x145x20': 0,
#  'filtro de aire(20)28113-1w000': 0,
#  'rotula del inf rh lh 54530-07000 cbkk-16': 0,
#  'filtro de gasolina(32)1457434442': 0,
#  'amortiguador del lh 333206': 0,
#  'cruceta de cardan yo55071 gut-21': 0,
#  'amortiguador del rh 333517': 0,
#  'kit de filtros(1)1° 2° a-5102+a-5103': 0,
#  'amortiguador post rh lh 343405': 0,
#  'estabilizadores del lh 54830-4h000 clkh-38l': 0,
#  'resorte del ori 12.5x156x365x6 12546': 0,
#  'amortiguador del rh 333205': 0,
#  'kit de filtros(4)1° 2° a-6006+a-6007***300': 0,
#  'kit de filtros(9)1°2°a-6703+a-6705': 0,
#  'filtro de aire af3014 pa2456 e1028l': 0,
#  'filtro de aire(9)28113-4e500***225': 0,
#  'filtro de aceite(25)per123 lf45': 0,
#  'kit filtro de aceite caja 1521527': 0,
#  'refrig rojo 50/50 hd prextoline': 0,
#  'filtro de aceite(6)pp112 l251': 0,
#  'kit de filtros 1°2°/1)a-2405+a-2406': 0,
#  'trapecio del lh inf  48069-0k090': 0,
#  'focos led h1 rpl2 12v 24v 19w 6500k': 0,
#  'filtro de aceite(6)lf9001 lf9080 ph8691': 0,
#  'actuador de corona': 0,
#  'filtro de aire lx1845 2e0129620b a-2625': 0,
#  'filtro de aceite(12)lf16285': 0,
#  'estabilizadores del rh lh 48820-02030 clt20': 0,
#  'palier 26x30x55.4 c/abs vw-078a48t': 0,
#  'amortiguador del rh 633177': 0,
#  'resorte post ref 15x118x445x8 1/2 13420': 0,
#  'filtro de aire(20)afl2223 afp7019': 0,
#  'palier 27x22x60 s/int abs/46': 0,
#  'aceite sae25w60 cf4 prextodiesel hv': 0,
#  'filtro de aire 2° 055135r1': 0,
#  'amortiguador post lh 333357': 0,
#  'amortiguador del lh 633178': 0,
#  'filtro de aceite(36)lf798 b141lf260***600': 0,
#  'amortiguador del lh 54660-2w100': 0,
#  'filtro de aire 1° af25565 af10299': 0,
#  'filtro de petroleo(50)per147b lfp68 r': 0,
#  'filtro de aire 2° af10308 af25566': 0,
#  'focos h27w/2 (9)': 0,
#  'trapecio del rh lh 45200-77500': 0,
#  'amortiguador del rh b2353': 0,
#  'filtro de aceite lf3977 per5200': 0,
#  'kit de filtros(12)1°2° as-2205+a-8568': 0,
#  'palier 22x30x51': 0,
#  'kit de filtros(4)1°2° a-8671+a-8670': 0,
#  'trapecio del rh inf  48068-0k090': 0,
#  'kit de filtros(4)1°2°a-5105+a-5106': 0,
#  'plato de embrague 203x137x237=ctx-014': 0,
#  'amortiguador del rh lh 365025': 0,
#  'plato de embrague 190mm': 0,
#  'amortiguador post rh 632103': 0,
#  'resorte post ori 16.2x104x329x8 1/4 3542': 0,
#  'filtro de aceite(12)ch8481 l1157 eo-2623': 0,
#  'rack end del rh lh 56540-0u500 crkh-40': 0,
#  'estabilizadores del rh 54840-4h000 clkh-38r': 0,
#  'amortiguador post rh 333356': 0,
#  'aceite sae75w90 fs synpower gl-5 mt1 1/4': 0,
#  'filtro de aire(20)17801-31130': 0,
#  'disco de freno delt vent bd7019 294x28x46.3x94x6': 0,
#  'amortiguador del rh 334502': 0,
#  'filtro de aire(20) a36101 afl1378': 0,
#  'palier 23x18x49 sk-202': 0,
#  'kit de filtros 1°2°(1)a-13580+a-13590': 0,
#  'amortiguador del lh 334701': 0,
#  'disco de embrague 200x140x20d': 0,
#  'kit de filtros(1)1°2° a-5301+a-6210': 0,
#  'filtro de aceite(16)15601-78140': 0,
#  'rack end del rh lh mr510267 crm-20': 0,
#  'resorte del ori 12.5x156x370x6 1/4 13415': 0,
#  'disco de embrague 180mm': 0,
#  'resorte post ori 16x145x320x5 1/2': 0,
#  'filtro de petroleo(50)lp9010 ff5764': 0,
#  'kit de filtros(25)1° 2° a-8504+a-7618***400': 0,
#  'amortiguador del rh 54650-2w100': 0,
#  'amortiguador del rh lh 633150': 0,
#  'kit de embrague dtx-146+ctx-115a': 0,
#  'filtro de aceite(12)lf3783': 0,
#  'filtro de aceite(12)l45262 simple***240': 0,
#  'trapecio del lh 48069-09240': 0,
#  'amortiguador del rh 334700': 0,
#  'kit de filtros(4)1° 2° a-69110+a-69120': 0,
#  'trapecio del rh 48068-09240': 0,
#  'amortiguador del lh b2354': 0,
#  'filtro de compre(25)af10140 afl6882': 0,
#  'disco de freno del bd2038 255x22x46.3x55x4': 0,
#  'filtro de aire(20)17801-30070': 0,
#  'filtro de aire(20)ca9021 mr-266849': 0,
#  'aceite sae10w30 sn synthetic 1/4': 0,
#  'resorte post ref 16.8x144x325x6 1/8 1703npg': 0,
#  'filtro de gasolina(25) 320/07155': 0,
#  'palier 26x24x58 c/anillo': 0,
#  'amortiguador post rh 341357': 0,
#  'resorte del ori 13x133x340x5 18394': 0,
#  'filtro de aire 1° pa5289': 0,
#  'filtro de cabina(20)97617-4h00': 0,
#  'filtro de aceite(25)lf4054 w-962': 0,
#  'filtro de aceite(50)per64 lf9': 0,
#  'focos 158 lagri mediana ambar': 0,
#  'amortiguador del lh 7246302l': 0,
#  'resorte del ori 13.7x156x375x5 1/2 3541': 0,
#  'filtro de aire(1)rs3710 af25560 a65347': 0,
#  'amortiguador del lh 334503': 0,
#  'resorte del ref 12.5x150x335x5 1/2 8505': 0,
#  'amortiguador post lh 341358': 0,
#  'amortiguador post': 0,
#  'filtro de aceite fco514 lf6815': 0,
#  'estabilizadores del lh 54830-0x000 clkh-42l': 0,
#  'palier 26x22x56  to-2029': 0,
#  'amortiguador del rh 7246302r': 0,
#  'kit de filtros(1)1°2°a-6707+a-6708': 0,
#  'resorte del ori 14.2x171x350x5 12721': 0,
#  'palier 23x21x56  rn-212': 0,
#  'filtro sep de agua(12)fs19816': 0,
#  'filtro de aire 1° 21115483 21243188***30': 0,
#  'rotula del rh lh sb-3962': 0,
#  'filtro de cabina(20) cu27007 afc3205': 0,
#  'filtro de aire(9)1° af25337m': 0,
#  'amortiguador post lh 333501': 0,
#  'amortiguador post rh lh 349085': 0,
#  'filtro de petroleo(50)23304-ev570': 0,
#  'filtro de aire(20)afl2093 13780-61i00': 0,
#  'resorte del ref 12.5x106.5x340x6 1807': 0,
#  'amortiguador post rh lh 349243': 0,
#  'palier 25x24x55 c/anillo ni-2032': 0,
#  'resorte del ori 17.2x127x338x6 3/4 5737': 0,
#  'resorte post ref 19.5x162x340x6 5797': 0,
#  'bocamaza del base  4h rodaje 43560-26010': 0,
#  'kit de filtros(1)1° 2° a-6830+a-6831***60': 0,
#  'resorte post ref 11.2x98x345x7 7/8 91': 0,
#  'kit de filtros(1) 1° 2° a-5639+a-5635***50': 0,
#  'palier 27x30x60 c/abs': 0,
#  'amortiguador del rh 334137': 0,
#  'kit de filtros(1)1º2º a-1828+a-7967': 0,
#  'filtro de aire 2° 1484437 1484497 af26678': 0,
#  'filtro de aire(20)a44467 afl2000': 0,
#  'rack end del rh/lh   56540-3x000 crkh-44': 0,
#  'filtro de petroleo(12)fco962 rc347aq ff5934': 0,
#  'trapecio del rh  54501-1y000': 0,
#  'amortiguador post rh 333500': 0,
#  'resorte post 14x82x295x6': 0,
#  'resorte post ref 13.2x147x330x5 5/8 9465': 0,
#  'bocamaza del base 4h rodaje 43570-60010 mod': 0,
#  'terminal del lh 9005917 ceg-11': 0,
#  'palier 25x20x50': 0,
#  'palier 27x23x62.2  mi-205': 0,
#  'kit de filtro aceite(16)o-1011+o-1010': 0,
#  'disco de embrague 275x175x21d=dt-602u': 0,
#  'amortiguador del lh 334138': 0,
#  'filtro de aceite lf3829': 0,
#  'resorte del ori 13.2x159x355x5 1/4 11691': 0,
#  'rotula del sup rh lh mr496792 cbm-32': 0,
#  'filtro sep de agua(6)2rd127491': 0,
#  'kit de embrague dtx-232a+ctx-170z+tks58-50k': 0,
#  'amortiguador del rh 632059': 0,
#  'refrig verde 50/50 zerex gln rtu afc': 0,
#  'filtro sep de agua(6)': 0,
#  'palier 29x36x67.2 c/anillo': 0,
#  'terminal del rh 9005918 ceg-10': 0,
#  'palier 22x22x52 c/anillo': 0,
#  'liquido de freno dot3 1lt 32 oz 946ml lata': 0,
#  'transf. a título gratuito narva': 0,
#  'filtro de aceite(30)w-719/45': 0,
#  'trapecio del lh  54500-1y000': 0,
#  'filtro de cabina(20)97133-d1000': 0,
#  'palier 30x33x69 c/abs': 0,
#  'resorte del ori 14x124x365x5 19111': 0,
#  'filtro de aceite(50) hu-919/6x': 0,
#  'focos led h11 rpl2 12v 24v 24w 6500k': 0,
#  'filtro de aceite(50) l960 c/drenaje***600': 0,
#  'filtro de aire 2° af25724 055130r1 ca9352sy': 0,
#  'rotula del infe rh lh 96535089 cbkd-10': 0,
#  'rotula del rh lh sb-t222': 0,
#  'filtro de petroleo(32)wk-820/18 c/sensor': 0,
#  'palier 27x23x56 c/anillo ni-2009': 0,
#  'pastillas de freno ceramica del d1950': 0,
#  'amortiguador del rh 333838': 0,
#  'terminal del ext rh 56820-1e900 cekh-36r': 0,
#  'filtro de aceite(20)per75 md-097003***800': 0,
#  'filtro de aire 2º 3979928 af26162': 0,
#  'amortiguador post rh lh 444178': 0,
#  'filtro de aire 2° pa5290': 0,
#  'palier 27x25x60 c/abs': 0,
#  'amortiguador del lh 632060': 0,
#  'resorte post gnv 13.2x138x250x6 1/2 5255': 0,
#  'amortiguador del lh 333239': 0,
#  'palier completo 30x29x72.5': 0,
#  'amortiguador del lh 338023': 0,
#  'filtro de aire(30)a35708': 0,
#  'filtro de aire(20)ca10696 c-32010': 0,
#  'filtro de aire(20)afl0113 zj01-13-z40': 0,
#  'resorte del ref 13x150x385x6': 0,
#  'amortiguador del rh lh 443238': 0,
#  'focos 715 t2w de tablero bala': 0,
#  'amortiguador post lh 632104': 0,
#  'terminal del ext lh 56820-1e000 cekh-36l': 0,
#  'focos 881(9)': 0,
#  'amortiguador del lh 333839': 0,
#  'filtro de aceite(25)fco531 lf3002 d/f': 0,
#  'filtro de aceite(50) 8-25010-633-0': 0,
#  'amortiguador post rh 332108': 0,
#  'pastillas de freno ceramica del d1471': 0,
#  'llantas deestone 73t r202': 0,
#  'amortiguador post rh lh 444024': 0,
#  'kit de filtros 1º2º(1)a-8656+a-83090***80': 0,
#  'pulmon de freno doble 8"(2)30/30 8121138 dorado': 0,
#  'filtro de aire 1°(1)c-341500/1 af25632': 0,
#  'llantas deestone 112t a/tr': 0,
#  'pastillas de freno ceramica del d1345': 0,
#  'filtro de aire(20)13780-63j00 chico': 0,
#  'filtro de aire(9)19336405': 0,
#  'rack end del rh lh 45503-52070 sr-ty020': 0,
#  'amortiguador post rh lh 348083': 0,
#  'kit de filtros 1°2"(4)a-13530+a-13540': 0,
#  'amortiguador post lh 332109': 0,
#  'kit de filtros(4)1° 2° a-5507+a-5508': 0,
#  'resorte post ref 14.7x122x280x5 3/4 5624': 0,
#  'kit de filtros(9)1º 2º as-6905+a-7965***270': 0,
#  'filtro de aire(16)af10188 afl4031hd': 0,
#  'terminal del ext lh 48640-3u025 cen-116': 0,
#  'filtro sep de agua(6)wk-10002/1x': 0,
#  'resorte del ref 12x129x350x6 18848': 0,
#  'rotula del sup rh lh 40110-2s485 cbn-62': 0,
#  'radiador mt version 16400-0l150': 0,
#  'filtro de petroleo(6)21407801 ff5935': 0,
#  'palier 29x25x56 c/abs': 0,
#  'filtro de aceite(50)11427541827': 0,
#  'cruceta de cardan 521 5-251x gu-1000': 0,
#  'filtro de aceite(50)5184526aa': 0,
#  'palier 26x30x55  ho-025': 0,
#  'terminal del ext rh 48520-3u025 cen-115': 0,
#  'kit de filtros 1°2°(1)a-7124+a-71250': 0,
#  'kit de filtros(1)1º2º a-5020+a-5021***100': 0,
#  'amortiguador del lh 632141': 0,
#  'valvula relay sealco': 0,
#  'filtro de aceite(50)15208-65f00': 0,
#  'resorte del ori 13.2x140x310x5 1/2 9511': 0,
#  'amortiguador del rh 333238': 0,
#  'trapecio del lh inf  48069-0k040': 0,
#  'kit de filtros(1)1°2° a-71130+a-71250': 0,
#  'filtro de aire(20)afl2163': 0,
#  'amortiguador del lh 332113': 0,
#  'resorte del ref 13.7x166x325x4 3/8 11440': 0,
#  'terminal del rh/lh 48810-84000 ces-12': 0,
#  'filtro de aire(20)fa300 afl2811': 0,
#  'filtro de aceite caja per18 lf18': 0,
#  'rack end del rh lh d8521-eb70a sr-n250': 0,
#  'llantas deestone 88h r201': 0,
#  'filtro de petroleo(12)pfc3181 lfp354': 0,
#  'filtro de aire(20) ca9728': 0,
#  'terminal del ext lh 45047-bz120 cet-185': 0,
#  'terminal del ext rh lh 45046-19175 cet-59': 0,
#  'trapecio del rh inf  48068-0k040': 0,
#  'filtro sep de agua(6)fs19735 20998367***60': 0,
#  'resorte post ref 16x119x400x6 3/4 12870': 0,
#  'filtro de petroleo(12)23304-ev021': 0,
#  'estabilizadores del rh 54840-0x000 clkh-42r': 0,
#  'filtro de aceite caja 2002705': 0,
#  'llantas deestone 102h 007 r601': 0,
#  'pulmon de freno doble 8"(2)30/30 8121138 negro': 0,
#  'amortiguador del rh 332112': 0,
#  'terminal del ext lh 45047-59026 cet-98': 0,
#  'resorte post ori 15x145x320x5 1/2 11145': 0,
#  'resorte post ref 13.5x96x325x8 1219 12999': 0,
#  'filtro de aire 1°(16)p505976 2465011': 0,
#  'resorte del ref 19.2x203x325x4 3/4 4771': 0,
#  'palier 25x23x54 c/anillo': 0,
#  'amortiguador del lh 332501': 0,
#  'terminal del ext rh 45046-59026 cet-99': 0,
#  'filtro de aceite bypass(25)320/04133***500': 0,
#  'disco de embrague 260x170x21d=dt-164u': 0,
#  'resorte post gnv 12x112x293x6 7/8 14201': 0,
#  'amortiguador del lh 634111': 0,
#  'palier 24x23x54 ni-234': 0,
#  'terminal del ext rh 56820-2s050 cekh-45r': 0,
#  'amortiguador del rh 632140': 0,
#  'filtro de petroleo(12)wk-1149': 0,
#  'palier 25x22x52.5': 0,
#  'actuador de caja transferencia': 0,
#  'terminal del ext lh 56820-2s000 cekh-45l': 0,
#  'terminal del ext rh 45046-bz120 cet-184': 0,
#  'estabilizadores del rh lh 54830-0u000 clkh-46': 0,
#  'filtro de aceite(12)w-950/26 lf16015': 0,
#  'pastillas de freno ceramica del d1543': 0,
#  'trapecio del rh sup 48066-29225': 0,
#  'bujia de encendido 3130': 0,
#  'amortiguador del rh 338022': 0,
#  'aceite sae25w60 cf4 valvodiesel': 0,
#  'terminal del ext lh 56820-1y500 cekk-37l': 0,
#  'amortiguador del rh lh 54650-4n000': 0,
#  'rack end del 48521-3u025 crn-41': 0,
#  'rack end del rh lh 45503-42030 sr-t220': 0,
#  'amortiguador del rh 634110': 0,
#  'filtro de aire(20)13780-65l00': 0,
#  'pastillas de freno ceramica d1567 delt': 0,
#  'resorte del ref 13.7x170x345x4 1/2 507': 0,
#  'filtro de petroleo felpa lp4700 p1007': 0,
#  'palier 22x22x52 c/abs torre alta': 0,
#  'estabilizadores del rh lh 48820-42030 sl-t220': 0,
#  'plato de embrague 210x145x247': 0,
#  'terminal del ext rh 56820-1y550 cekk-37r': 0,
#  'estabilizadores del rh lh bp4k-34-170d sl-1650': 0,
#  'rack end del rh lh 57724-1e000 crkh-29': 0,
#  'filtro de petroleo(50)23304-78260': 0,
#  'palier 24x19x52  mz-2012': 0,
#  'disco de embrague 224x150x21d': 0,
#  'amortiguador del rh 332500': 0,
#  'palier 24x22x56 c/anillo to-2808': 0,
#  'pastillas de freno ceramica del d1210': 0,
#  'pastillas de freno ceramica del d1184': 0,
#  'filtro de aire 1°(4)af4506 afl3602hd': 0,
#  'palier 26x21x55.5 c/anillo s/abs': 0,
#  'pulmon de freno 8"(4)1h tkl23017c 1608006': 0,
#  'palier 27x25x56': 0,
#  'filtro de aceite(25)57047 ch9972': 0,
#  'amortiguador post rh lh 444169': 0,
#  'aceite sae15w40 gas geo': 0,
#  'focos 158 lagri mediana w3w': 0,
#  'rack end del rh lh 57724-2p000 crkk-40r': 0,
#  'palier 26x22x56 c/anillo': 0,
#  'cremallera hidraulica 44250-0k730': 0,
#  'palier 25x20x50 mi-810': 0,
#  'filtro sep de agua(50)pf59830 fs20103': 0,
#  'terminal del lh 45047-49135 se-t221l': 0,
#  'filtro sep de agua(12)wk-940/26 fs19735***240': 0,
#  'amortiguador del lh 634084': 0,
#  'amortiguador del rh 634083': 0,
#  'terminal del rh 45046-49195 se-t221r': 0,
#  'rotula del sup rh lh 40110-eb70d cbn-74': 0,
#  'bombin de embrague 13/16': 0,
#  'estabilizadores del rh lh 48820-26050 clt-51': 0,
#  'amortiguador del lh 95032447': 0,
#  'filtro de aire(16)17801-30050': 0,
#  'disco de freno del bd2884 275x22x46.5x55x5': 0,
#  'resorte del 11x92x275x9': 0,
#  'filtro de cabina(20)52425938': 0,
#  'filtro de aire 1° af25727 rs3942 p778984': 0,
#  'filtro de aire(20)afl476 ca9367': 0,
#  'trapecio del lh sup 48067-29225': 0,
#  'filtro de aceite(6)0k87a14317': 0,
#  'amortiguador del rh 95032448': 0,
#  'amortiguador del rh 3330039': 0,
#  'filtro de agua(12)lfw2010 wf2071': 0,
#  'resorte post gnv 11.5x77x365x8 679': 0,
#  'amortiguador del rh 96424025sp': 0,
#  'filtros de petroleo(50)94771044': 0,
#  'filtro de aire(20)28113-b9000': 0,
#  'collarin de embrague mrk': 0,
#  'filtro de aire(20) ca10497': 0,
#  'filtro de aceite(75)w75/2 per583 ph5796 lf177': 0,
#  'pastillas de freno ceramica del d2289': 0,
#  'resorte post ori 14x144x392x6 1/2 12179': 0,
#  'bomba de aceite 15100-21030': 0,
#  'resorte post ref 13x132x395x6 3/4 13102': 0,
#  'kit de filtros 1°2°(9) as-1014+a-7919': 0,
#  'filtro de aire 2º 21115501 23294956': 0,
#  'refrig rojo max 50/50 af lln toyota gln': 0,
#  'resorte post ref 15x96x280x6': 0,
#  'focos h4 (5) rallye': 0,
#  'filtro de aire(8)af10276 af25584m': 0,
#  'aceite sae5w30 sp synthetic': 0,
#  'llantas deestone 121/118q 10pr r408': 0,
#  'amortiguador del lh 96424026sp': 0,
#  'filtro sep de agua(6)fs19769 c/vaso': 0,
#  'filtro de cabina(20)97133-f2000': 0,
#  'amortiguador post rh lh 55300-4h600': 0,
#  'terminal del ext lh 45047-09080 cet-112l': 0,
#  'focos led rpl2 12v 24v h8 h11 h16 6500k niebla': 0,
#  'rack end del rh lh 45503-12130 sr-3640': 0,
#  'torreta del c/rodaje 95227628': 0,
#  'pastillas de freno ceramica del d242': 0,
#  'filtro de aire(20)ca9482 afl2202': 0,
#  'kit de filtros 1°2°(9)as-7813+a-7964***306': 0,
#  'terminal del ext rh mr-508136 cem-51r': 0,
#  'aceite atf mercon v 1/4': 0,
#  'pastillas de freno ceramica del d684': 0,
#  'amortiguador del rh 633147': 0,
#  'filtro de petroleo(25)fco544 lfp544**300': 0,
#  'filtro de aire(20) c-28010 afl2162': 0,
#  'filtro sep de agua(50)2010sm 2 micron': 0,
#  'terminal del ext rh 45046-09200 cet-112r': 0,
#  'kit de filtros(1)1°2°a-8553+a-8554': 0,
#  'amortiguador del lh 3330040': 0,
#  'filtro de aire(20)96950990': 0,
#  'filtro sep de agua(6)fs19914 1292404': 0,
#  'filtro de cabina(20)27277-en000': 0,
#  'pastillas de freno ceramica post d1423 d1354': 0,
#  'terminal del ext lh mr-508135 cem-51l': 0,
#  'kit de filtros(1)1º 2º a-5535+a-5534': 0,
#  'trapecio del lh 96535082': 0,
#  'focos h3 rpw 2 pzas(5)': 0,
#  'amortiguador del lh 633148': 0,
#  'pastillas de freno ceramica del d1592': 0,
#  'filtro de aire 2°  1759847': 0,
#  'torreta del 48609-0k040': 0,
#  'amortiguador post rh lh 444023': 0,
#  'estabilizadores post rh lh 48830-20010 sl-2805': 0,
#  'filtro de petroleo(20) p10695': 0,
#  'filtro de petroleo felpa lp160': 0,
#  ...}

# %%
data['cod_nombre_articulo'] = data.nombre_articulo.map(nombre_articulo_dict)
data
# Out:
#             fecha                              razon_social  \
# 0      2021-01-04              casas sovero daniela yamilet
# 1      2021-01-04              casas sovero daniela yamilet
# 2      2021-01-04                 gc service & parts s.a.c.
# 3      2021-01-05               lopez rosales yolanda juana
# 4      2021-01-06                     palante flotas s.a.c.
# ...           ...                                       ...
# 576016 2024-05-17  empresa de transportes sol de oro s.a.c.
# 576017 2024-05-22     lubricentro virgen del rosario s.r.l.
# 576018 2024-05-22     lubricentro virgen del rosario s.r.l.
# 576019 2024-05-23                     gqr autopartes s.a.c.
# 576020 2024-05-23                     gqr autopartes s.a.c.
#
#                                nombre_articulo       fuente_suministro  \
# 0                             focos h1 12v 55w                   narva
# 1                focos h4 12v 100x90 rallye(7)                   narva
# 2           filtro de aire 1° af25729 055134r1           mann - brasil
# 3       pastillas de freno ceramica d1567 delt      wagner - pastillas
# 4                    aceite sae20w50 sn racing               valvoline
# ...                                        ...                     ...
# 576016               llantas himito nl118 18pr                 deruibo
# 576017        trapecio del lh inf  48069-0k090  ito koyama - trapecios
# 576018        trapecio del rh inf  48068-0k090  ito koyama - trapecios
# 576019         palier 25x23x55 c/anillo ni-214   ito koyama - palieres
# 576020                 copa de palier 23x31x34   ito koyama - palieres
#
#         cantidad  venta_usd  venta_pen        costo  \
# 0           50.0      51.27     185.80   134.870000
# 1          300.0     597.46    2165.20  1413.050100
# 2            8.0     152.54     552.80   310.150000
# 3            2.0      42.36     153.68    96.560000
# 4           90.0     861.86    3129.41  2323.670040
# ...          ...        ...        ...          ...
# 576016      20.0    2796.61   10425.76  7899.060000
# 576017       1.0      59.92     223.68   119.090000
# 576018       1.0      59.92     223.68   118.290000
# 576019       6.0      63.94     239.33   159.430002
# 576020      16.0     202.79     759.04   529.950000
#
#                              cobrador      mes  departamento_num  \
# 0                 vega zúñiga enrique  2021-01               1.0
# 1                 vega zúñiga enrique  2021-01               1.0
# 2                             oficina  2021-01               1.0
# 3              cañas flores alan joel  2021-01               4.0
# 4             olórtegui manrique juan  2021-01               1.0
# ...                               ...      ...               ...
# 576016  fernández monge juan fernando  2024-05               1.0
# 576017   valderrama acuña luisa maria  2024-05               2.0
# 576018   valderrama acuña luisa maria  2024-05               2.0
# 576019            vega zúñiga enrique  2024-05               1.0
# 576020            vega zúñiga enrique  2024-05               1.0
#
#         cod_vendedor  cod_razon_social  cod_cobrador  cod_nombre_articulo
# 0                 13                 0             3                    0
# 1                 13                 0             3                    0
# 2                 28                 0             0                    0
# 3                 21                 0             0                    0
# 4                 30                 0             1                    0
# ...              ...               ...           ...                  ...
# 576016            22                 0             2                    0
# 576017             0                 0             0                    0
# 576018             0                 0             0                    0
# 576019            24                 0             3                    0
# 576020            24                 0             3                    0
#
# [576021 rows x 15 columns]

# %%
data.fuente_suministro.value_counts().head(25).sum()/data.fuente_suministro.value_counts().sum()
# Out:
# np.float64(0.9534511882420545)

# %%
fuente_sumistro_list = list( data.fuente_suministro.value_counts().index )

# %%
fuente_sumistro_dict = {suministro: i + 1 if i < 25 else 0 for i , suministro in enumerate(fuente_sumistro_list)}
fuente_sumistro_dict
# Out:
# {'sakura filter': 1,
#  'ito koyama - amortiguadores': 2,
#  'ito koyama - resortes': 3,
#  'narva': 4,
#  'mann - brasil': 5,
#  'ito koyama - direccion': 6,
#  'ito koyama - palieres': 7,
#  'aisin - japon': 8,
#  'ito koyama - trapecios': 9,
#  'ishikawa - pastillas de freno': 10,
#  'sin definicion': 11,
#  'valvoline - usa': 12,
#  'valvoline': 13,
#  'ishikawa - discos de freno': 14,
#  'prextoline - lubricantes': 15,
#  'seco - embragues': 16,
#  'denso - bujias - japon': 17,
#  'deestone': 18,
#  'ito koyama - bocamazas': 19,
#  'wagner - pastillas': 20,
#  'ito koyama - torretas': 21,
#  'wagner locked - usa': 22,
#  'tkl - taiwan': 23,
#  'prestone - usa': 24,
#  'prestone - mexico': 25,
#  'versachem - usa': 0,
#  'spaco - italia': 0,
#  'rover - usa': 0,
#  'monark - alemania': 0,
#  'skf - rodajes': 0,
#  'ks - alemania': 0,
#  'sakura - radiadores': 0,
#  'novaquimica - peru': 0,
#  'toyo - japon': 0,
#  'prextoline - usa': 0,
#  'clevite - usa': 0,
#  'ito koyama - cremalleras': 0,
#  'nachi - koyo - ntn - nsk - japon': 0,
#  'moog - usa': 0,
#  'deruibo': 0,
#  'plumillas - sakura': 0,
#  'ishikawa - zapatas de freno': 0,
#  'sankei - japon': 0,
#  'nas - pfi - zkl - mba': 0,
#  'wix filters': 0,
#  'prextoline - grasas': 0,
#  'birene - cigueñales-culatas-ejes de levas': 0,
#  'marilia': 0,
#  'sealco  - usa': 0,
#  'mrk - japon': 0,
#  'collarines - nachi - koyo -  nsk - japon': 0,
#  'philips': 0,
#  'enertech - encendido': 0,
#  'sabo- brasil': 0,
#  'german cardan - t v a - crucetas': 0,
#  'ks - brasil': 0,
#  'nas - chumaceras': 0,
#  'baldwin filters': 0,
#  'fras-le': 0,
#  'ctr': 0,
#  'cei - italia': 0,
#  'timken - rodajes': 0,
#  'cas': 0,
#  'vdo -  brasil': 0,
#  'varga': 0,
#  'kamura': 0,
#  'zsg - taiwan': 0,
#  'garrett - brasil': 0,
#  'gmb - bombas de agua': 0,
#  'trw - brasil': 0,
#  'victor reinz - alemania': 0,
#  'crc - limpia carburador': 0,
#  'sachs - brasil': 0,
#  'glyco - alemania': 0,
#  'kawe - embragues': 0,
#  'zf - alemania': 0,
#  'laso': 0,
#  'donaldson': 0,
#  'chumaceras - japon': 0,
#  'vkntech': 0,
#  'mahle - brasil': 0,
#  'goetze': 0,
#  'fag - alemania': 0,
#  'denso - elementos - valvulas': 0,
#  'tezuka - japon': 0,
#  'corteco - brasil': 0,
#  'precision - usa': 0,
#  'fp diesel - usa': 0,
#  'contitech - bolsas de aire': 0,
#  'daewha  - korea': 0,
#  'mirage': 0,
#  'affinia nakata - brasil': 0,
#  'owrun - aros de rueda': 0,
#  'delphi - cav - brasil': 0,
#  'lemforder - brasil': 0,
#  'zy diesel': 0,
#  'zekiturbo': 0,
#  'osvat': 0,
#  'sealed power - usa': 0,
#  'affinia urba - brasil': 0,
#  'indeco - cables': 0,
#  'sachs - argentina': 0,
#  'boto tyres': 0}

# %%
data['cod_suministro'] = data.fuente_suministro.map(fuente_sumistro_dict)
data
# Out:
#             fecha                              razon_social  \
# 0      2021-01-04              casas sovero daniela yamilet
# 1      2021-01-04              casas sovero daniela yamilet
# 2      2021-01-04                 gc service & parts s.a.c.
# 3      2021-01-05               lopez rosales yolanda juana
# 4      2021-01-06                     palante flotas s.a.c.
# ...           ...                                       ...
# 576016 2024-05-17  empresa de transportes sol de oro s.a.c.
# 576017 2024-05-22     lubricentro virgen del rosario s.r.l.
# 576018 2024-05-22     lubricentro virgen del rosario s.r.l.
# 576019 2024-05-23                     gqr autopartes s.a.c.
# 576020 2024-05-23                     gqr autopartes s.a.c.
#
#                                nombre_articulo       fuente_suministro  \
# 0                             focos h1 12v 55w                   narva
# 1                focos h4 12v 100x90 rallye(7)                   narva
# 2           filtro de aire 1° af25729 055134r1           mann - brasil
# 3       pastillas de freno ceramica d1567 delt      wagner - pastillas
# 4                    aceite sae20w50 sn racing               valvoline
# ...                                        ...                     ...
# 576016               llantas himito nl118 18pr                 deruibo
# 576017        trapecio del lh inf  48069-0k090  ito koyama - trapecios
# 576018        trapecio del rh inf  48068-0k090  ito koyama - trapecios
# 576019         palier 25x23x55 c/anillo ni-214   ito koyama - palieres
# 576020                 copa de palier 23x31x34   ito koyama - palieres
#
#         cantidad  venta_usd  venta_pen        costo  \
# 0           50.0      51.27     185.80   134.870000
# 1          300.0     597.46    2165.20  1413.050100
# 2            8.0     152.54     552.80   310.150000
# 3            2.0      42.36     153.68    96.560000
# 4           90.0     861.86    3129.41  2323.670040
# ...          ...        ...        ...          ...
# 576016      20.0    2796.61   10425.76  7899.060000
# 576017       1.0      59.92     223.68   119.090000
# 576018       1.0      59.92     223.68   118.290000
# 576019       6.0      63.94     239.33   159.430002
# 576020      16.0     202.79     759.04   529.950000
#
#                              cobrador      mes  departamento_num  \
# 0                 vega zúñiga enrique  2021-01               1.0
# 1                 vega zúñiga enrique  2021-01               1.0
# 2                             oficina  2021-01               1.0
# 3              cañas flores alan joel  2021-01               4.0
# 4             olórtegui manrique juan  2021-01               1.0
# ...                               ...      ...               ...
# 576016  fernández monge juan fernando  2024-05               1.0
# 576017   valderrama acuña luisa maria  2024-05               2.0
# 576018   valderrama acuña luisa maria  2024-05               2.0
# 576019            vega zúñiga enrique  2024-05               1.0
# 576020            vega zúñiga enrique  2024-05               1.0
#
#         cod_vendedor  cod_razon_social  cod_cobrador  cod_nombre_articulo  \
# 0                 13                 0             3                    0
# 1                 13                 0             3                    0
# 2                 28                 0             0                    0
# 3                 21                 0             0                    0
# 4                 30                 0             1                    0
# ...              ...               ...           ...                  ...
# 576016            22                 0             2                    0
# 576017             0                 0             0                    0
# 576018             0                 0             0                    0
# 576019            24                 0             3                    0
# 576020            24                 0             3                    0
#
#         cod_suministro
# 0                  4.0
# 1                  4.0
# 2                  5.0
# 3                 20.0
# 4                 13.0
# ...                ...
# 576016             0.0
# 576017             9.0
# 576018             9.0
# 576019             7.0
# 576020             7.0
#
# [576021 rows x 16 columns]

# %%
data.drop(['razon_social', 'nombre_articulo', 'fuente_suministro', 'cobrador'], axis=1, inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 576021 entries, 0 to 576020
# Data columns (total 12 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   fecha                576021 non-null  datetime64[ns]
#  1   cantidad             576021 non-null  float64
#  2   venta_usd            576021 non-null  float64
#  3   venta_pen            576021 non-null  float64
#  4   costo                576021 non-null  float64
#  5   mes                  576021 non-null  period[M]
#  6   departamento_num     576010 non-null  float64
#  7   cod_vendedor         576021 non-null  int64
#  8   cod_razon_social     576021 non-null  int64
#  9   cod_cobrador         576021 non-null  int64
#  10  cod_nombre_articulo  576021 non-null  int64
#  11  cod_suministro       576019 non-null  float64
# dtypes: datetime64[ns](1), float64(6), int64(4), period[M](1)
# memory usage: 52.7 MB

# %%
data.describe()
# Out:
#                                fecha       cantidad      venta_usd  \
# count                         576021  576021.000000  576021.000000
# mean   2022-09-08 12:39:35.688386304      23.846181     124.581396
# min              2021-01-04 00:00:00       0.300000       0.000000
# 25%              2021-10-22 00:00:00       2.000000      23.940000
# 50%              2022-08-26 00:00:00       5.000000      48.830000
# 75%              2023-07-27 00:00:00      12.000000     108.470000
# max              2024-05-31 00:00:00   45000.000000   30254.240000
# std                              NaN     226.730771     336.646284
#
#            venta_pen          costo  departamento_num   cod_vendedor  \
# count  576021.000000  576021.000000     576010.000000  576021.000000
# mean      475.438098     313.715927          4.790337      11.734303
# min         0.000000       0.180000          1.000000       0.000000
# 25%        91.490000      54.000000          1.000000       3.000000
# 50%       186.970000     111.650000          2.000000      11.000000
# 75%       413.780000     255.820000          7.000000      18.000000
# max    117628.490000   67296.816000         25.000000      35.000000
# std      1289.009821     935.095311          5.312281       9.167783
#
#        cod_razon_social   cod_cobrador  cod_nombre_articulo  cod_suministro
# count     576021.000000  576021.000000        576021.000000   576019.000000
# mean           0.846153       4.685301             0.883476        4.645279
# min            0.000000       0.000000             0.000000        0.000000
# 25%            0.000000       1.000000             0.000000        1.000000
# 50%            0.000000       3.000000             0.000000        3.000000
# 75%            0.000000       7.000000             0.000000        6.000000
# max           20.000000      20.000000            20.000000       25.000000
# std            3.161923       4.871126             3.279255        5.207105

# %%
#pd.plotting.scatter_matrix(data, alpha=0.8, figsize=(20,15))

# %%
data.hist(figsize=(20,15), bins= 15)
# Out:
# array([[<Axes: title={'center': 'fecha'}>,
#         <Axes: title={'center': 'cantidad'}>,
#         <Axes: title={'center': 'venta_usd'}>],
#        [<Axes: title={'center': 'venta_pen'}>,
#         <Axes: title={'center': 'costo'}>,
#         <Axes: title={'center': 'departamento_num'}>],
#        [<Axes: title={'center': 'cod_vendedor'}>,
#         <Axes: title={'center': 'cod_razon_social'}>,
#         <Axes: title={'center': 'cod_cobrador'}>],
#        [<Axes: title={'center': 'cod_nombre_articulo'}>,
#         <Axes: title={'center': 'cod_suministro'}>, <Axes: >]],
#       dtype=object)

# %%
data.cod_nombre_articulo.value_counts()
# Out:
# cod_nombre_articulo
# 0     522663
# 1       3644
# 2       3366
# 3       3292
# 4       3287
# 5       3256
# 6       2925
# 7       2843
# 8       2692
# 9       2628
# 10      2622
# 11      2462
# 12      2398
# 13      2368
# 14      2359
# 15      2276
# 16      2266
# 17      2211
# 18      2207
# 19      2135
# 20      2121
# Name: count, dtype: int64

# %%
ventas.nombre_articulo.value_counts().head(20)
# Out:
# nombre_articulo
# filtro sep de agua(6)lfwp9000 fs19532           3644
# focos 1034 2 cont p21/5w                        3366
# amortiguador del rh                             3292
# amortiguador del lh                             3287
# filtro de petroleo(50)8-98162-897-0             3256
# filtro de petroleo(25)1457434310                2925
# focos 93 1 cont 1141 p21w                       2843
# kit de filtros(1)1º2º a-1325+a-1330             2692
# amortiguador post rh lh                         2628
# focos h4 60x55w p43t-38                         2622
# filtro sep de agua(6)ps6643 fco553a             2462
# filtro de aceite(50)fco515 lf3007 lf3537        2398
# filtro de petroleo(25)8-98092481-1              2368
# focos 158 lagri mediana w5w                     2359
# aceite sae5w30 sn synthetic glx1.25gl 5/4       2276
# aceite sae10w30 sn semi sintetico               2266
# aceite aw68 prextofluid iso68 ambar             2211
# filtro de aceite(6)lf7205 lf3818                2207
# focos 67 r5w                                    2135
# kit de filtros(9)1° 2° a-5541+a-5540 af25692    2121
# Name: count, dtype: int64

# %%
matrix_corr = data.drop(['mes'],axis=1)
matrix_corr = matrix_corr.corr('pearson')
matrix_corr
# Out:
#                         fecha  cantidad  venta_usd  venta_pen     costo  \
# fecha                1.000000 -0.004331   0.017585   0.013345  0.010249
# cantidad            -0.004331  1.000000   0.329566   0.333144  0.355499
# venta_usd            0.017585  0.329566   1.000000   0.999364  0.979390
# venta_pen            0.013345  0.333144   0.999364   1.000000  0.980303
# costo                0.010249  0.355499   0.979390   0.980303  1.000000
# departamento_num    -0.000586 -0.026955  -0.017585  -0.017596 -0.017503
# cod_vendedor        -0.023125 -0.009592   0.027605   0.027819  0.027476
# cod_razon_social    -0.050167 -0.014660  -0.012641  -0.012544 -0.020224
# cod_cobrador         0.019892 -0.016394  -0.006701  -0.006784 -0.009362
# cod_nombre_articulo -0.004004  0.097393   0.087939   0.088249  0.084502
# cod_suministro       0.063964 -0.001202   0.119181   0.118616  0.127786
#
#                      departamento_num  cod_vendedor  cod_razon_social  \
# fecha                       -0.000586     -0.023125         -0.050167
# cantidad                    -0.026955     -0.009592         -0.014660
# venta_usd                   -0.017585      0.027605         -0.012641
# venta_pen                   -0.017596      0.027819         -0.012544
# costo                       -0.017503      0.027476         -0.020224
# departamento_num             1.000000     -0.008920         -0.131463
# cod_vendedor                -0.008920      1.000000          0.006597
# cod_razon_social            -0.131463      0.006597          1.000000
# cod_cobrador                 0.388545     -0.035631         -0.030870
# cod_nombre_articulo         -0.006586      0.011306         -0.034507
# cod_suministro               0.047777      0.019239         -0.081341
#
#                      cod_cobrador  cod_nombre_articulo  cod_suministro
# fecha                    0.019892            -0.004004        0.063964
# cantidad                -0.016394             0.097393       -0.001202
# venta_usd               -0.006701             0.087939        0.119181
# venta_pen               -0.006784             0.088249        0.118616
# costo                   -0.009362             0.084502        0.127786
# departamento_num         0.388545            -0.006586        0.047777
# cod_vendedor            -0.035631             0.011306        0.019239
# cod_razon_social        -0.030870            -0.034507       -0.081341
# cod_cobrador             1.000000            -0.010218        0.022840
# cod_nombre_articulo     -0.010218             1.000000       -0.014400
# cod_suministro           0.022840            -0.014400        1.000000

# %%
import seaborn as sns 
plt.figure(figsize=(10,6))
sns.heatmap(matrix_corr, annot= True)
plt.show()
